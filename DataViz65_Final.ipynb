# %% [markdown]
# <a href="https://colab.research.google.com/github/Supansapkb/BasicProg_DataViz65/blob/main/DataViz65_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# จุดมุ่งหมาย: ตัดเกรดรายวิชา Project และวาดกราฟแสดงผลการสอบดังรายละเอียดต่อไปนี้

# %%
#เชื่อม google drive 
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#เข้าไป path ใน google drive
import os
os.chdir('/content/drive/MyDrive/final')

# !pwd #เช็ค paht ที่กำลังทำงานอยู่
# Out:
# /content/drive/MyDrive/final

# %%
# !ls #ดูว่ามีไฟล์อะไรบ้าง
# Out:
# คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx	คะแนนสอบปากเปล่าของกรรมการสอบ_renamed.xlsx

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 🔗Open file

# %%
 import pandas as pd

# %% [markdown]
# ##คะแนนสอบปากเปล่าของกรรมการสอบ_renamed.xlsx ชีท 1

# %%
day0 = pd.read_excel('/content/drive/MyDrive/final/คะแนนสอบปากเปล่าของกรรมการสอบ_renamed.xlsx',sheet_name=0,skiprows=1)
day0.head()
# Out:
#    ห้องสอบ              เวลา  \
# 0      NaN               NaN
# 1  SC 6501  08:00 – 10.00 น.
# 2      NaN               NaN
# 3      NaN               NaN
# 4      NaN               NaN
#
#                                           ชื่อเรื่อง              นักศึกษา  \
# 0                                                NaN                   NaN
# 1  1.การศึกษาแนวทางการประกันภัยพืชผลสำหรับมันสำปะ...  leaky-rust-chameleon
# 2                                                NaN    greasy-ruby-bombay
# 3                                                NaN  leaky-rust-chameleon
# 4                                                NaN    greasy-ruby-bombay
#
#      อาจารย์  กรรมการสอบ  ความชัดเจนของโจทย์การวิจัย  \
# 0  ที่ปรึกษา         NaN                          10
# 1  ดร.ธิปไตย  ผศ.วุฒิชัย                           8
# 2        NaN         NaN                           8
# 3        NaN    อ.ยุภาพร                           9
# 4        NaN         NaN                           9
#
# ...

# %%
day0_1 = day0.fillna(method='ffill')
day0_1.head()
# Out:
#    ห้องสอบ              เวลา  \
# 0      NaN               NaN
# 1  SC 6501  08:00 – 10.00 น.
# 2  SC 6501  08:00 – 10.00 น.
# 3  SC 6501  08:00 – 10.00 น.
# 4  SC 6501  08:00 – 10.00 น.
#
#                                           ชื่อเรื่อง              นักศึกษา  \
# 0                                                NaN                   NaN
# 1  1.การศึกษาแนวทางการประกันภัยพืชผลสำหรับมันสำปะ...  leaky-rust-chameleon
# 2  1.การศึกษาแนวทางการประกันภัยพืชผลสำหรับมันสำปะ...    greasy-ruby-bombay
# 3  1.การศึกษาแนวทางการประกันภัยพืชผลสำหรับมันสำปะ...  leaky-rust-chameleon
# 4  1.การศึกษาแนวทางการประกันภัยพืชผลสำหรับมันสำปะ...    greasy-ruby-bombay
#
#      อาจารย์  กรรมการสอบ  ความชัดเจนของโจทย์การวิจัย  \
# 0  ที่ปรึกษา         NaN                          10
# 1  ดร.ธิปไตย  ผศ.วุฒิชัย                           8
# 2  ดร.ธิปไตย  ผศ.วุฒิชัย                           8
# 3  ดร.ธิปไตย    อ.ยุภาพร                           9
# 4  ดร.ธิปไตย    อ.ยุภาพร                           9
#
# ...

# %% [markdown]
# ###ตรวจสอบค่า missing

# %%
day0_1.isnull().any() #ตรวจสอบค่าสูญหาย
# Out:
# ห้องสอบ                                           True
# เวลา                                              True
# ชื่อเรื่อง                                        True
# นักศึกษา                                          True
# อาจารย์                                          False
# กรรมการสอบ                                        True
# ความชัดเจนของโจทย์การวิจัย                       False
# ความครอบคลุมของทฤษฎีและ วรรณกรรมที่เกี่ยวข้อง    False
# ความถูกต้องของระเบียบวิธีวิจัย                   False
# สื่อการนำเสนอ                                    False
# ความสามารถในการนำเสนอและตอบคำถาม                 False
# ความถูกต้องของเนื้อหาในเล่มรายงาน                False
# รวม                                              False
# dtype: bool

# %%
day0_1 = day0_1.dropna(subset=['ห้องสอบ', 'เวลา','ชื่อเรื่อง','นักศึกษา','กรรมการสอบ'])

# %%
day0_1.isnull().any() #ตรวจสอบค่าสูญหาย
# Out:
# ห้องสอบ                                          False
# เวลา                                             False
# ชื่อเรื่อง                                       False
# นักศึกษา                                         False
# อาจารย์                                          False
# กรรมการสอบ                                       False
# ความชัดเจนของโจทย์การวิจัย                       False
# ความครอบคลุมของทฤษฎีและ วรรณกรรมที่เกี่ยวข้อง    False
# ความถูกต้องของระเบียบวิธีวิจัย                   False
# สื่อการนำเสนอ                                    False
# ความสามารถในการนำเสนอและตอบคำถาม                 False
# ความถูกต้องของเนื้อหาในเล่มรายงาน                False
# รวม                                              False
# dtype: bool

# %%
day0_1.head()
# Out:
#    ห้องสอบ              เวลา  \
# 1  SC 6501  08:00 – 10.00 น.
# 2  SC 6501  08:00 – 10.00 น.
# 3  SC 6501  08:00 – 10.00 น.
# 4  SC 6501  08:00 – 10.00 น.
# 5  SC 6501  10:00 – 12.00 น.
#
#                                           ชื่อเรื่อง              นักศึกษา  \
# 1  1.การศึกษาแนวทางการประกันภัยพืชผลสำหรับมันสำปะ...  leaky-rust-chameleon
# 2  1.การศึกษาแนวทางการประกันภัยพืชผลสำหรับมันสำปะ...    greasy-ruby-bombay
# 3  1.การศึกษาแนวทางการประกันภัยพืชผลสำหรับมันสำปะ...  leaky-rust-chameleon
# 4  1.การศึกษาแนวทางการประกันภัยพืชผลสำหรับมันสำปะ...    greasy-ruby-bombay
# 5  2.การศึกษาการทำประกันภัยพืชผลจากภัยแล้งโดยใช้ค...   wiggy-silver-drever
#
#      อาจารย์  กรรมการสอบ  ความชัดเจนของโจทย์การวิจัย  \
# 1  ดร.ธิปไตย  ผศ.วุฒิชัย                           8
# 2  ดร.ธิปไตย  ผศ.วุฒิชัย                           8
# 3  ดร.ธิปไตย    อ.ยุภาพร                           9
# 4  ดร.ธิปไตย    อ.ยุภาพร                           9
# 5  ดร.ธิปไตย  ผศ.วุฒิชัย                           8
#
# ...

# %% [markdown]
# ##คะแนนสอบปากเปล่าของกรรมการสอบ_renamed.xlsx ชีท 2

# %%
day1 = pd.read_excel('/content/drive/MyDrive/final/คะแนนสอบปากเปล่าของกรรมการสอบ_renamed.xlsx',sheet_name=1,skiprows=1)
day1.head()
# Out:
#    ห้องสอบ              เวลา  \
# 0      NaN               NaN
# 1  SC 6501  08:00 – 10.00 น.
# 2      NaN               NaN
# 3      NaN               NaN
# 4      NaN               NaN
#
#                                           ชื่อเรื่อง  \
# 0                                                NaN
# 1  15.การพัฒนาระบบสารสนเทศเพื่อสืบค้นโครงงานผ่านเ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                      นักศึกษา    อาจารย์ กรรมการสอบ  \
# 0                         NaN  ที่ปรึกษา        NaN
# 1            tasty-myrtle-ant  รศ.วิชุดา  ดร.ธนพงศ์
# 2  skanky-burgundy-kingfisher        NaN        NaN
# 3            tasty-myrtle-ant        NaN   ดร.พลากร
# 4  skanky-burgundy-kingfisher        NaN        NaN
#
#    ความชัดเจนของโจทย์การวิจัย  ความครอบคลุมของทฤษฎีและ วรรณกรรมที่เกี่ยวข้อง  \
# ...

# %%
day1_1 = day1.fillna(method='ffill')
day1_1.head()
# Out:
#    ห้องสอบ              เวลา  \
# 0      NaN               NaN
# 1  SC 6501  08:00 – 10.00 น.
# 2  SC 6501  08:00 – 10.00 น.
# 3  SC 6501  08:00 – 10.00 น.
# 4  SC 6501  08:00 – 10.00 น.
#
#                                           ชื่อเรื่อง  \
# 0                                                NaN
# 1  15.การพัฒนาระบบสารสนเทศเพื่อสืบค้นโครงงานผ่านเ...
# 2  15.การพัฒนาระบบสารสนเทศเพื่อสืบค้นโครงงานผ่านเ...
# 3  15.การพัฒนาระบบสารสนเทศเพื่อสืบค้นโครงงานผ่านเ...
# 4  15.การพัฒนาระบบสารสนเทศเพื่อสืบค้นโครงงานผ่านเ...
#
#                      นักศึกษา    อาจารย์ กรรมการสอบ  \
# 0                         NaN  ที่ปรึกษา        NaN
# 1            tasty-myrtle-ant  รศ.วิชุดา  ดร.ธนพงศ์
# 2  skanky-burgundy-kingfisher  รศ.วิชุดา  ดร.ธนพงศ์
# 3            tasty-myrtle-ant  รศ.วิชุดา   ดร.พลากร
# 4  skanky-burgundy-kingfisher  รศ.วิชุดา   ดร.พลากร
#
#    ความชัดเจนของโจทย์การวิจัย  ความครอบคลุมของทฤษฎีและ วรรณกรรมที่เกี่ยวข้อง  \
# ...

# %% [markdown]
# ### ตรวจสอบค่า missing

# %%
day1_1.isnull().any() #ตรวจสอบค่าสูญหาย
# Out:
# ห้องสอบ                                           True
# เวลา                                              True
# ชื่อเรื่อง                                        True
# นักศึกษา                                          True
# อาจารย์                                          False
# กรรมการสอบ                                        True
# ความชัดเจนของโจทย์การวิจัย                       False
# ความครอบคลุมของทฤษฎีและ วรรณกรรมที่เกี่ยวข้อง    False
# ความถูกต้องของระเบียบวิธีวิจัย                   False
# สื่อการนำเสนอ                                    False
# ความสามารถในการนำเสนอและตอบคำถาม                 False
# ความถูกต้องของเนื้อหาในเล่มรายงาน                False
# รวม                                              False
# dtype: bool

# %%
day1_1 = day1_1.dropna(subset=['ห้องสอบ', 'เวลา','ชื่อเรื่อง','นักศึกษา','กรรมการสอบ'])

# %%
day1_1.isnull().any() #ตรวจสอบค่าสูญหาย
# Out:
# ห้องสอบ                                          False
# เวลา                                             False
# ชื่อเรื่อง                                       False
# นักศึกษา                                         False
# อาจารย์                                          False
# กรรมการสอบ                                       False
# ความชัดเจนของโจทย์การวิจัย                       False
# ความครอบคลุมของทฤษฎีและ วรรณกรรมที่เกี่ยวข้อง    False
# ความถูกต้องของระเบียบวิธีวิจัย                   False
# สื่อการนำเสนอ                                    False
# ความสามารถในการนำเสนอและตอบคำถาม                 False
# ความถูกต้องของเนื้อหาในเล่มรายงาน                False
# รวม                                              False
# dtype: bool

# %%
day1_1.head()
# Out:
#    ห้องสอบ              เวลา  \
# 1  SC 6501  08:00 – 10.00 น.
# 2  SC 6501  08:00 – 10.00 น.
# 3  SC 6501  08:00 – 10.00 น.
# 4  SC 6501  08:00 – 10.00 น.
# 5  SC 6501  10:00 – 12.00 น.
#
#                                           ชื่อเรื่อง  \
# 1  15.การพัฒนาระบบสารสนเทศเพื่อสืบค้นโครงงานผ่านเ...
# 2  15.การพัฒนาระบบสารสนเทศเพื่อสืบค้นโครงงานผ่านเ...
# 3  15.การพัฒนาระบบสารสนเทศเพื่อสืบค้นโครงงานผ่านเ...
# 4  15.การพัฒนาระบบสารสนเทศเพื่อสืบค้นโครงงานผ่านเ...
# 5  16.การพัฒนาระบบฐานข้อมูลเพื่อคัดกรองนักศึกษาที...
#
#                      นักศึกษา    อาจารย์ กรรมการสอบ  \
# 1            tasty-myrtle-ant  รศ.วิชุดา  ดร.ธนพงศ์
# 2  skanky-burgundy-kingfisher  รศ.วิชุดา  ดร.ธนพงศ์
# 3            tasty-myrtle-ant  รศ.วิชุดา   ดร.พลากร
# 4  skanky-burgundy-kingfisher  รศ.วิชุดา   ดร.พลากร
# 5          sleazy-mauve-akita  รศ.วิชุดา  ดร.ธนพงศ์
#
#    ความชัดเจนของโจทย์การวิจัย  ความครอบคลุมของทฤษฎีและ วรรณกรรมที่เกี่ยวข้อง  \
# ...

# %% [markdown]
# ##คะแนนสอบปากเปล่าของกรรมการสอบ_renamed.xlsx ชีท 3

# %%
day2 = pd.read_excel('/content/drive/MyDrive/final/คะแนนสอบปากเปล่าของกรรมการสอบ_renamed.xlsx',sheet_name=2,skiprows=1)
day2.head()
# Out:
#    ห้องสอบ              เวลา  \
# 0      NaN               NaN
# 1  SC 6501  08:00 – 10.00 น.
# 2      NaN               NaN
# 3      NaN  10:00 – 12.00 น.
# 4      NaN               NaN
#
#                                           ชื่อเรื่อง                นักศึกษา  \
# 0                                                NaN                     NaN
# 1  29.พฤติกรรมการใช้แอพพลิเคชั่นในการเรียนออนไลน์...      frumpy-gamboge-emu
# 2                                                NaN                     NaN
# 3  30.ความคิดเห็นของนักศึกษาเกี่ยวกับคุณภาพสารสนเ...  ugly-harlequin-octopus
# 4                                                NaN   craggy-cream-paradise
#
#      อาจารย์  กรรมการสอบ  ความชัดเจนของโจทย์การวิจัย  \
# 0  ที่ปรึกษา         NaN                        10.0
# 1  รศ.วิชุดา   ดร.ธิปไตย                         8.0
# 2        NaN  รศ.สุพรรณี                         6.0
# 3  รศ.วิชุดา   ดร.ธิปไตย                         9.0
# ...

# %%
day2_1 = day2.fillna(method='ffill')
day2_1.head()
# Out:
#    ห้องสอบ              เวลา  \
# 0      NaN               NaN
# 1  SC 6501  08:00 – 10.00 น.
# 2  SC 6501  08:00 – 10.00 น.
# 3  SC 6501  10:00 – 12.00 น.
# 4  SC 6501  10:00 – 12.00 น.
#
#                                           ชื่อเรื่อง                นักศึกษา  \
# 0                                                NaN                     NaN
# 1  29.พฤติกรรมการใช้แอพพลิเคชั่นในการเรียนออนไลน์...      frumpy-gamboge-emu
# 2  29.พฤติกรรมการใช้แอพพลิเคชั่นในการเรียนออนไลน์...      frumpy-gamboge-emu
# 3  30.ความคิดเห็นของนักศึกษาเกี่ยวกับคุณภาพสารสนเ...  ugly-harlequin-octopus
# 4  30.ความคิดเห็นของนักศึกษาเกี่ยวกับคุณภาพสารสนเ...   craggy-cream-paradise
#
#      อาจารย์  กรรมการสอบ  ความชัดเจนของโจทย์การวิจัย  \
# 0  ที่ปรึกษา         NaN                        10.0
# 1  รศ.วิชุดา   ดร.ธิปไตย                         8.0
# 2  รศ.วิชุดา  รศ.สุพรรณี                         6.0
# 3  รศ.วิชุดา   ดร.ธิปไตย                         9.0
# ...

# %% [markdown]
# ### ตรวจสอบค่า missing

# %%
day2_1.isnull().any() #ตรวจสอบค่าสูญหาย
# Out:
# ห้องสอบ                                           True
# เวลา                                              True
# ชื่อเรื่อง                                        True
# นักศึกษา                                          True
# อาจารย์                                          False
# กรรมการสอบ                                        True
# ความชัดเจนของโจทย์การวิจัย                       False
# ความครอบคลุมของทฤษฎีและ วรรณกรรมที่เกี่ยวข้อง    False
# ความถูกต้องของระเบียบวิธีวิจัย                   False
# สื่อการนำเสนอ                                    False
# ความสามารถในการนำเสนอและตอบคำถาม                 False
# ความถูกต้องของเนื้อหาในเล่มรายงาน                False
# รวม                                              False
# dtype: bool

# %%
day2_1 = day2_1.dropna(subset=['ห้องสอบ', 'เวลา','ชื่อเรื่อง','นักศึกษา','กรรมการสอบ'])

# %%
day2_1.isnull().any() #ตรวจสอบค่าสูญหาย
# Out:
# ห้องสอบ                                          False
# เวลา                                             False
# ชื่อเรื่อง                                       False
# นักศึกษา                                         False
# อาจารย์                                          False
# กรรมการสอบ                                       False
# ความชัดเจนของโจทย์การวิจัย                       False
# ความครอบคลุมของทฤษฎีและ วรรณกรรมที่เกี่ยวข้อง    False
# ความถูกต้องของระเบียบวิธีวิจัย                   False
# สื่อการนำเสนอ                                    False
# ความสามารถในการนำเสนอและตอบคำถาม                 False
# ความถูกต้องของเนื้อหาในเล่มรายงาน                False
# รวม                                              False
# dtype: bool

# %%
day2_1.head()
# Out:
#    ห้องสอบ              เวลา  \
# 1  SC 6501  08:00 – 10.00 น.
# 2  SC 6501  08:00 – 10.00 น.
# 3  SC 6501  10:00 – 12.00 น.
# 4  SC 6501  10:00 – 12.00 น.
# 5  SC 6501  10:00 – 12.00 น.
#
#                                           ชื่อเรื่อง                นักศึกษา  \
# 1  29.พฤติกรรมการใช้แอพพลิเคชั่นในการเรียนออนไลน์...      frumpy-gamboge-emu
# 2  29.พฤติกรรมการใช้แอพพลิเคชั่นในการเรียนออนไลน์...      frumpy-gamboge-emu
# 3  30.ความคิดเห็นของนักศึกษาเกี่ยวกับคุณภาพสารสนเ...  ugly-harlequin-octopus
# 4  30.ความคิดเห็นของนักศึกษาเกี่ยวกับคุณภาพสารสนเ...   craggy-cream-paradise
# 5  30.ความคิดเห็นของนักศึกษาเกี่ยวกับคุณภาพสารสนเ...  ugly-harlequin-octopus
#
#      อาจารย์  กรรมการสอบ  ความชัดเจนของโจทย์การวิจัย  \
# 1  รศ.วิชุดา   ดร.ธิปไตย                         8.0
# 2  รศ.วิชุดา  รศ.สุพรรณี                         6.0
# 3  รศ.วิชุดา   ดร.ธิปไตย                         9.0
# 4  รศ.วิชุดา   ดร.ธิปไตย                         9.0
# ...

# %% [markdown]
# ##คะแนนอาจารย์

# %%
all_aj_list = set(list(day0_1['กรรมการสอบ'].dropna()))
all_aj_list
# Out:
# {'ดร.ธนพงศ์',
#  'ดร.ธิปไตย',
#  'ดร.พลากร',
#  'ดร.วรรณพร',
#  'ดร.อุทุมพร',
#  'ผศ.วุฒิชัย',
#  'ผศ.สุกัญญา',
#  'รศ.วิชุดา',
#  'อ.ธรรณญพร',
#  'อ.ยุภาพร'}

# %% [markdown]
# ### advisor1 ดร.ธนพงศ์

# %%
advisor1 = pd.read_excel('/content/drive/MyDrive/final/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',sheet_name='ดร.ธนพงศ์',skiprows=1)
advisor1.head()
# Out:
#                  Unnamed: 0  \
# 0                       NaN
# 1       jumpy-apricot-frise
# 2  boozy-thistle-wildebeest
# 3      hasty-magnolia-devil
# 4   chummy-goldenrod-walrus
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
# 3                                                  5
# 4                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
# 3                                                  5
# 4                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# ...

# %%
advisor1.rename(columns={'Unnamed: 0': 'ชื่อ-สกุล', 'Unnamed: 12': 'ชื่อเรื่อง'}, inplace=True)
advisor1.head(3)
# Out:
#                   ชื่อ-สกุล  \
# 0                       NaN
# 1       jumpy-apricot-frise
# 2  boozy-thistle-wildebeest
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# 0                                                 10
# 1                                                 10
# 2                                                  9
#
#    4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)  \
# 0                                      5
# ...

# %% [markdown]
# #### ตรวจสอบค่า missing

# %%
advisor1.isnull().any() #ตรวจสอบค่าสูญหาย
# Out:
# ชื่อ-สกุล                                                                                     True
# 1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ    False
# 2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย                   False
# 3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา                                 False
# 4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)                                                        False
# 5. ความใส่ใจในการจัดพิมพ์เอกสาร เช่น ความถูกต้อง การแก้ไขตามที่ให้ข้อเสนอแนะไปแล้ว           False
# 6. สามารถควบคุมโครงงานให้ดำเนินการเป็นไปตามแผน                                               False
# 7. ความคิดสร้างสรรค์ ความสามารถวางแผนในการทำงาน การแก้ปัญหาในระหว่างการทำงาน                 False
# ความสมบูรณ์ของเล่ม (8.1 การค้นคว้าข้อมูล หรือแสวงหาความรู้เพิ่มเติม)                         False
# ...

# %%
advisor1.dtypes  # ตรวจสอบประเภทของข้อมูล
# Out:
# ชื่อ-สกุล                                                                                    object
# 1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ     int64
# 2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย                    int64
# 3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา                                  int64
# 4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)                                                         int64
# 5. ความใส่ใจในการจัดพิมพ์เอกสาร เช่น ความถูกต้อง การแก้ไขตามที่ให้ข้อเสนอแนะไปแล้ว            int64
# 6. สามารถควบคุมโครงงานให้ดำเนินการเป็นไปตามแผน                                                int64
# 7. ความคิดสร้างสรรค์ ความสามารถวางแผนในการทำงาน การแก้ปัญหาในระหว่างการทำงาน                  int64
# ความสมบูรณ์ของเล่ม (8.1 การค้นคว้าข้อมูล หรือแสวงหาความรู้เพิ่มเติม)                          int64
# ...

# %%
advisor1 = advisor1.fillna(method='ffill')
advisor1.head()
# Out:
#                   ชื่อ-สกุล  \
# 0                       NaN
# 1       jumpy-apricot-frise
# 2  boozy-thistle-wildebeest
# 3      hasty-magnolia-devil
# 4   chummy-goldenrod-walrus
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
# 3                                                  5
# 4                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
# 3                                                  5
# 4                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# ...

# %%
advisor1.isnull().any() #ตรวจสอบค่าสูญหาย
# Out:
# ชื่อ-สกุล                                                                                     True
# 1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ    False
# 2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย                   False
# 3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา                                 False
# 4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)                                                        False
# 5. ความใส่ใจในการจัดพิมพ์เอกสาร เช่น ความถูกต้อง การแก้ไขตามที่ให้ข้อเสนอแนะไปแล้ว           False
# 6. สามารถควบคุมโครงงานให้ดำเนินการเป็นไปตามแผน                                               False
# 7. ความคิดสร้างสรรค์ ความสามารถวางแผนในการทำงาน การแก้ปัญหาในระหว่างการทำงาน                 False
# ความสมบูรณ์ของเล่ม (8.1 การค้นคว้าข้อมูล หรือแสวงหาความรู้เพิ่มเติม)                         False
# ...

# %%
advisor1 = advisor1.dropna(subset=['ชื่อ-สกุล','ชื่อเรื่อง'])

# %%
advisor1.isnull().any() #ตรวจสอบค่าสูญหาย
# Out:
# ชื่อ-สกุล                                                                                    False
# 1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ    False
# 2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย                   False
# 3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา                                 False
# 4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)                                                        False
# 5. ความใส่ใจในการจัดพิมพ์เอกสาร เช่น ความถูกต้อง การแก้ไขตามที่ให้ข้อเสนอแนะไปแล้ว           False
# 6. สามารถควบคุมโครงงานให้ดำเนินการเป็นไปตามแผน                                               False
# 7. ความคิดสร้างสรรค์ ความสามารถวางแผนในการทำงาน การแก้ปัญหาในระหว่างการทำงาน                 False
# ความสมบูรณ์ของเล่ม (8.1 การค้นคว้าข้อมูล หรือแสวงหาความรู้เพิ่มเติม)                         False
# ...

# %%
advisor1.head()
# Out:
#                   ชื่อ-สกุล  \
# 1       jumpy-apricot-frise
# 2  boozy-thistle-wildebeest
# 3      hasty-magnolia-devil
# 4   chummy-goldenrod-walrus
# 5        randy-gamboge-blue
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 1                                                  5
# 2                                                  4
# 3                                                  5
# 4                                                  5
# 5                                                  4
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 1                                                  5
# 2                                                  4
# 3                                                  5
# 4                                                  5
# 5                                                  4
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# ...

# %% [markdown]
# ### advisor2 ดร.ธิปไตย

# %%
advisor2 = pd.read_excel('/content/drive/MyDrive/final/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',sheet_name='ดร.ธิปไตย',skiprows=1)
advisor2.head()
# Out:
#              Unnamed: 0  \
# 0                   NaN
# 1  leaky-rust-chameleon
# 2    greasy-ruby-bombay
# 3   wiggy-silver-drever
# 4       stinky-red-chow
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
# 3                                                  5
# 4                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# ...

# %%
advisor2.rename(columns={'Unnamed: 0': 'ชื่อ-สกุล', 'Unnamed: 12': 'ชื่อเรื่อง'}, inplace=True)
advisor2.head(3)
# Out:
#               ชื่อ-สกุล  \
# 0                   NaN
# 1  leaky-rust-chameleon
# 2    greasy-ruby-bombay
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# 0                                                 10
# 1                                                  9
# 2                                                  7
#
#    4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)  \
# 0                                      5
# 1                                      5
# ...

# %% [markdown]
# #### ตรวจสอบค่า missing

# %%
advisor2 = advisor2.fillna(method='ffill')
advisor2
# Out:
#               ชื่อ-สกุล  \
# 0                   NaN
# 1  leaky-rust-chameleon
# 2    greasy-ruby-bombay
# 3   wiggy-silver-drever
# 4       stinky-red-chow
# 5  bumpy-indigo-dolphin
# 6   randy-rust-lionfish
# 7    flaky-sepia-setter
# 8    pasty-tomato-okapi
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
# 3                                                  5
# 4                                                  5
# 5                                                  5
# 6                                                  4
# 7                                                  5
# 8                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# ...

# %%
advisor2.isnull().any() #ตรวจสอบค่าสูญหาย
# Out:
# ชื่อ-สกุล                                                                                     True
# 1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ    False
# 2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย                   False
# 3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา                                 False
# 4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)                                                        False
# 5. ความใส่ใจในการจัดพิมพ์เอกสาร เช่น ความถูกต้อง การแก้ไขตามที่ให้ข้อเสนอแนะไปแล้ว           False
# 6. สามารถควบคุมโครงงานให้ดำเนินการเป็นไปตามแผน                                               False
# 7. ความคิดสร้างสรรค์ ความสามารถวางแผนในการทำงาน การแก้ปัญหาในระหว่างการทำงาน                 False
# ความสมบูรณ์ของเล่ม (8.1 การค้นคว้าข้อมูล หรือแสวงหาความรู้เพิ่มเติม)                         False
# ...

# %%
advisor2 = advisor2.dropna(subset=['ชื่อ-สกุล', 'ชื่อเรื่อง'])

# %%
advisor2
# Out:
#               ชื่อ-สกุล  \
# 1  leaky-rust-chameleon
# 2    greasy-ruby-bombay
# 3   wiggy-silver-drever
# 4       stinky-red-chow
# 5  bumpy-indigo-dolphin
# 6   randy-rust-lionfish
# 7    flaky-sepia-setter
# 8    pasty-tomato-okapi
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 1                                                  5
# 2                                                  4
# 3                                                  5
# 4                                                  5
# 5                                                  5
# 6                                                  4
# 7                                                  5
# 8                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 1                                                  5
# 2                                                  5
# ...

# %% [markdown]
# ### advisor3 ดร.พลากร

# %%
advisor3 = pd.read_excel('/content/drive/MyDrive/final/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',sheet_name='ดร.พลากร',skiprows=1)
advisor3.head()
# Out:
#               Unnamed: 0  \
# 0                    NaN
# 1  craggy-mustard-sponge
# 2    fuzzy-silver-discus
# 3        lousy-corn-mule
# 4   muggy-charcoal-akita
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  4
# 2                                                  4
# 3                                                  5
# 4                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  4
# 2                                                  4
# 3                                                  5
# 4                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# ...

# %%
advisor3.rename(columns={'Unnamed: 0': 'ชื่อ-สกุล', 'Unnamed: 12': 'ชื่อเรื่อง'}, inplace=True)
advisor3.head(3)
# Out:
#                ชื่อ-สกุล  \
# 0                    NaN
# 1  craggy-mustard-sponge
# 2    fuzzy-silver-discus
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  4
# 2                                                  4
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  4
# 2                                                  4
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# 0                                                 10
# 1                                                  8
# 2                                                  8
#
#    4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)  \
# 0                                      5
# 1                                      5
# ...

# %% [markdown]
# #### ตรวจสอบค่า missing

# %%
advisor3.isnull().any() #ตรวจสอบค่าสูญหาย
# Out:
# ชื่อ-สกุล                                                                                     True
# 1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ    False
# 2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย                   False
# 3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา                                 False
# 4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)                                                        False
# 5. ความใส่ใจในการจัดพิมพ์เอกสาร เช่น ความถูกต้อง การแก้ไขตามที่ให้ข้อเสนอแนะไปแล้ว           False
# 6. สามารถควบคุมโครงงานให้ดำเนินการเป็นไปตามแผน                                               False
# 7. ความคิดสร้างสรรค์ ความสามารถวางแผนในการทำงาน การแก้ปัญหาในระหว่างการทำงาน                 False
# ความสมบูรณ์ของเล่ม (8.1 การค้นคว้าข้อมูล หรือแสวงหาความรู้เพิ่มเติม)                         False
# ...

# %%
advisor3 = advisor3.fillna(method='ffill')
advisor3.head()
# Out:
#                ชื่อ-สกุล  \
# 0                    NaN
# 1  craggy-mustard-sponge
# 2    fuzzy-silver-discus
# 3        lousy-corn-mule
# 4   muggy-charcoal-akita
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  4
# 2                                                  4
# 3                                                  5
# 4                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  4
# 2                                                  4
# 3                                                  5
# 4                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# ...

# %%
advisor3 = advisor3.dropna(subset=['ชื่อ-สกุล', 'ชื่อเรื่อง'])

# %%
advisor3.isnull().any() #ตรวจสอบค่าสูญหาย
# Out:
# ชื่อ-สกุล                                                                                    False
# 1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ    False
# 2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย                   False
# 3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา                                 False
# 4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)                                                        False
# 5. ความใส่ใจในการจัดพิมพ์เอกสาร เช่น ความถูกต้อง การแก้ไขตามที่ให้ข้อเสนอแนะไปแล้ว           False
# 6. สามารถควบคุมโครงงานให้ดำเนินการเป็นไปตามแผน                                               False
# 7. ความคิดสร้างสรรค์ ความสามารถวางแผนในการทำงาน การแก้ปัญหาในระหว่างการทำงาน                 False
# ความสมบูรณ์ของเล่ม (8.1 การค้นคว้าข้อมูล หรือแสวงหาความรู้เพิ่มเติม)                         False
# ...

# %%
advisor3
# Out:
#                      ชื่อ-สกุล  \
# 1        craggy-mustard-sponge
# 2          fuzzy-silver-discus
# 3              lousy-corn-mule
# 4         muggy-charcoal-akita
# 5  stinky-wisteria-nightingale
# 6            hazy-aqua-peccary
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 1                                                  4
# 2                                                  4
# 3                                                  5
# 4                                                  5
# 5                                                  5
# 6                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 1                                                  4
# 2                                                  4
# 3                                                  5
# 4                                                  5
# ...

# %% [markdown]
# ### advisor4 ดร.วรรณพร

# %%
advisor4 = pd.read_excel('/content/drive/MyDrive/final/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',sheet_name='ดร.วรรณพร',skiprows=1)
advisor4.head()
# Out:
#                Unnamed: 0  \
# 0                     NaN
# 1  skinny-bronze-dormouse
# 2    freaky-lemon-peccary
# 3       flabby-green-fish
# 4  skinny-heliotrope-kudu
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# ...

# %%
advisor4.rename(columns={'Unnamed: 0': 'ชื่อ-สกุล', 'Unnamed: 12': 'ชื่อเรื่อง'}, inplace=True)
advisor4.head(3)
# Out:
#                 ชื่อ-สกุล  \
# 0                     NaN
# 1  skinny-bronze-dormouse
# 2    freaky-lemon-peccary
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# 0                                                 10
# 1                                                  8
# 2                                                  7
#
#   4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)  \
# 0                                     5
# 1                                     5
# ...

# %% [markdown]
# #### ตรวจสอบค่า missing

# %%
advisor4.isnull().any() #ตรวจสอบค่าสูญหาย
# Out:
# ชื่อ-สกุล                                                                                     True
# 1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ    False
# 2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย                   False
# 3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา                                 False
# 4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)                                                        False
# 5. ความใส่ใจในการจัดพิมพ์เอกสาร เช่น ความถูกต้อง การแก้ไขตามที่ให้ข้อเสนอแนะไปแล้ว           False
# 6. สามารถควบคุมโครงงานให้ดำเนินการเป็นไปตามแผน                                               False
# 7. ความคิดสร้างสรรค์ ความสามารถวางแผนในการทำงาน การแก้ปัญหาในระหว่างการทำงาน                 False
# ความสมบูรณ์ของเล่ม (8.1 การค้นคว้าข้อมูล หรือแสวงหาความรู้เพิ่มเติม)                         False
# ...

# %%
advisor4 = advisor4.fillna(method='ffill')
advisor4.head()
# Out:
#                 ชื่อ-สกุล  \
# 0                     NaN
# 1  skinny-bronze-dormouse
# 2    freaky-lemon-peccary
# 3       flabby-green-fish
# 4  skinny-heliotrope-kudu
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# ...

# %%
advisor4 = advisor4.dropna(subset=['ชื่อ-สกุล', 'ชื่อเรื่อง'])

# %%
advisor4
# Out:
#                 ชื่อ-สกุล  \
# 1  skinny-bronze-dormouse
# 2    freaky-lemon-peccary
# 3       flabby-green-fish
# 4  skinny-heliotrope-kudu
# 5      messy-white-toucan
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
# 5                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
# 5                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# ...

# %% [markdown]
# ### advisor5 ดร.อุทุมพร

# %%
advisor5 = pd.read_excel('/content/drive/MyDrive/final/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',sheet_name='ดร.อุทุมพร',skiprows=1)
advisor5.head()
# Out:
#                 Unnamed: 0  \
# 0                      NaN
# 1      chummy-azure-walrus
# 2        breezy-pear-macaw
# 3  cozy-tangerine-ladybird
# 4     scaly-pumpkin-monkey
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  4
# 4                                                  4
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# ...

# %%
advisor5.rename(columns={'Unnamed: 0': 'ชื่อ-สกุล', 'Unnamed: 12': 'ชื่อเรื่อง'}, inplace=True)
advisor5.head(3)
# Out:
#              ชื่อ-สกุล  \
# 0                  NaN
# 1  chummy-azure-walrus
# 2    breezy-pear-macaw
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# 0                                                 10
# 1                                                  9
# 2                                                 10
#
#    4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)  \
# 0                                      5
# 1                                      5
# ...

# %% [markdown]
# #### ตรวจสอบค่า missing

# %%
advisor5.isnull().any() #ตรวจสอบค่าสูญหาย
# Out:
# ชื่อ-สกุล                                                                                     True
# 1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ    False
# 2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย                   False
# 3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา                                 False
# 4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)                                                        False
# 5. ความใส่ใจในการจัดพิมพ์เอกสาร เช่น ความถูกต้อง การแก้ไขตามที่ให้ข้อเสนอแนะไปแล้ว           False
# 6. สามารถควบคุมโครงงานให้ดำเนินการเป็นไปตามแผน                                               False
# 7. ความคิดสร้างสรรค์ ความสามารถวางแผนในการทำงาน การแก้ปัญหาในระหว่างการทำงาน                 False
# ความสมบูรณ์ของเล่ม (8.1 การค้นคว้าข้อมูล หรือแสวงหาความรู้เพิ่มเติม)                         False
# ...

# %%
advisor5 = advisor5.fillna(method='ffill')
advisor5.head()
# Out:
#                  ชื่อ-สกุล  \
# 0                      NaN
# 1      chummy-azure-walrus
# 2        breezy-pear-macaw
# 3  cozy-tangerine-ladybird
# 4     scaly-pumpkin-monkey
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  4
# 4                                                  4
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# ...

# %%
advisor5 = advisor5.dropna(subset=['ชื่อ-สกุล', 'ชื่อเรื่อง'])

# %%
advisor5
# Out:
#                   ชื่อ-สกุล  \
# 1       chummy-azure-walrus
# 2         breezy-pear-macaw
# 3   cozy-tangerine-ladybird
# 4      scaly-pumpkin-monkey
# 5  scanty-razzmatazz-rabbit
# 6        grumpy-flax-bonobo
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 1                                                  5
# 2                                                  5
# 3                                                  4
# 4                                                  4
# 5                                                  5
# 6                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
# ...

# %% [markdown]
# ### advisor6 ผศ.วุฒิชัย

# %%
advisor6 = pd.read_excel('/content/drive/MyDrive/final/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',sheet_name='ผศ.วุฒิชัย',skiprows=1)
advisor6.head()
# Out:
#               Unnamed: 0  \
# 0                    NaN
# 1     lumpy-carmine-slug
# 2  snappy-azure-balinese
# 3     pasty-bronze-booby
# 4  pokey-asparagus-frise
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  4
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# ...

# %%
advisor6.rename(columns={'Unnamed: 0': 'ชื่อ-สกุล', 'Unnamed: 12': 'ชื่อเรื่อง'}, inplace=True)
advisor6.head(3)
# Out:
#                ชื่อ-สกุล  \
# 0                    NaN
# 1     lumpy-carmine-slug
# 2  snappy-azure-balinese
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# 0                                                 10
# 1                                                 10
# 2                                                  9
#
#    4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)  \
# 0                                    5.0
# 1                                    NaN
# ...

# %% [markdown]
# #### ตรวจสอบค่า missing

# %%
advisor6 = advisor6.fillna(method='ffill')
advisor6.head()
# Out:
#                ชื่อ-สกุล  \
# 0                    NaN
# 1     lumpy-carmine-slug
# 2  snappy-azure-balinese
# 3     pasty-bronze-booby
# 4  pokey-asparagus-frise
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  4
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# ...

# %%
advisor6.isnull().any() #ตรวจสอบค่าสูญหาย
# Out:
# ชื่อ-สกุล                                                                                     True
# 1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ    False
# 2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย                   False
# 3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา                                 False
# 4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)                                                        False
# 5. ความใส่ใจในการจัดพิมพ์เอกสาร เช่น ความถูกต้อง การแก้ไขตามที่ให้ข้อเสนอแนะไปแล้ว           False
# 6. สามารถควบคุมโครงงานให้ดำเนินการเป็นไปตามแผน                                               False
# 7. ความคิดสร้างสรรค์ ความสามารถวางแผนในการทำงาน การแก้ปัญหาในระหว่างการทำงาน                 False
# ความสมบูรณ์ของเล่ม (8.1 การค้นคว้าข้อมูล หรือแสวงหาความรู้เพิ่มเติม)                         False
# ...

# %%
advisor6 = advisor6.dropna(subset=['ชื่อ-สกุล', 'ชื่อเรื่อง'])

# %%
advisor6.isnull().any() #ตรวจสอบค่าสูญหาย
# Out:
# ชื่อ-สกุล                                                                                    False
# 1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ    False
# 2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย                   False
# 3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา                                 False
# 4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)                                                        False
# 5. ความใส่ใจในการจัดพิมพ์เอกสาร เช่น ความถูกต้อง การแก้ไขตามที่ให้ข้อเสนอแนะไปแล้ว           False
# 6. สามารถควบคุมโครงงานให้ดำเนินการเป็นไปตามแผน                                               False
# 7. ความคิดสร้างสรรค์ ความสามารถวางแผนในการทำงาน การแก้ปัญหาในระหว่างการทำงาน                 False
# ความสมบูรณ์ของเล่ม (8.1 การค้นคว้าข้อมูล หรือแสวงหาความรู้เพิ่มเติม)                         False
# ...

# %%
advisor6
# Out:
#                  ชื่อ-สกุล  \
# 1       lumpy-carmine-slug
# 2    snappy-azure-balinese
# 3       pasty-bronze-booby
# 4    pokey-asparagus-frise
# 5  randy-charcoal-flamingo
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
# 5                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  4
# 5                                                  4
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# ...

# %% [markdown]
# ### advisor7 ผศ.สุกัญญา

# %%
advisor7 = pd.read_excel('/content/drive/MyDrive/final/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',sheet_name='ผศ.สุกัญญา',skiprows=1)
advisor7.head()
# Out:
#                 Unnamed: 0  \
# 0                      NaN
# 1         whiny-pear-otter
# 2    craggy-cream-reindeer
# 3       cloudy-myrtle-kudu
# 4  lovely-asparagus-urchin
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# ...

# %%
advisor7.rename(columns={'Unnamed: 0': 'ชื่อ-สกุล', 'Unnamed: 12': 'ชื่อเรื่อง'}, inplace=True)
advisor7.head(3)
# Out:
#                ชื่อ-สกุล  \
# 0                    NaN
# 1       whiny-pear-otter
# 2  craggy-cream-reindeer
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# 0                                                 10
# 1                                                  8
# 2                                                  8
#
#    4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)  \
# 0                                      5
# 1                                      5
# ...

# %% [markdown]
# #### ตรวจสอบค่า missing

# %%
advisor7.isnull().any() #ตรวจสอบค่าสูญหาย
# Out:
# ชื่อ-สกุล                                                                                     True
# 1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ    False
# 2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย                   False
# 3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา                                 False
# 4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)                                                        False
# 5. ความใส่ใจในการจัดพิมพ์เอกสาร เช่น ความถูกต้อง การแก้ไขตามที่ให้ข้อเสนอแนะไปแล้ว           False
# 6. สามารถควบคุมโครงงานให้ดำเนินการเป็นไปตามแผน                                               False
# 7. ความคิดสร้างสรรค์ ความสามารถวางแผนในการทำงาน การแก้ปัญหาในระหว่างการทำงาน                 False
# ความสมบูรณ์ของเล่ม (8.1 การค้นคว้าข้อมูล หรือแสวงหาความรู้เพิ่มเติม)                         False
# ...

# %%
advisor7 = advisor7.fillna(method='ffill')
advisor7.head()
# Out:
#                  ชื่อ-สกุล  \
# 0                      NaN
# 1         whiny-pear-otter
# 2    craggy-cream-reindeer
# 3       cloudy-myrtle-kudu
# 4  lovely-asparagus-urchin
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# ...

# %%
advisor7 = advisor7.dropna(subset=['ชื่อ-สกุล', 'ชื่อเรื่อง'])

# %%
advisor7.head()
# Out:
#                  ชื่อ-สกุล  \
# 1         whiny-pear-otter
# 2    craggy-cream-reindeer
# 3       cloudy-myrtle-kudu
# 4  lovely-asparagus-urchin
# 5  clammy-zucchini-chicken
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
# 5                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
# 5                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# ...

# %% [markdown]
# ### advisor8 รศ.วิชุดา

# %%
advisor8 = pd.read_excel('/content/drive/MyDrive/final/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',sheet_name='รศ.วิชุดา',skiprows=1)
advisor8.head()
# Out:
#                    Unnamed: 0  \
# 0                         NaN
# 1            tasty-myrtle-ant
# 2  skanky-burgundy-kingfisher
# 3          sleazy-mauve-akita
# 4       crappy-burgundy-quoll
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                5.0
# 1                                                5.0
# 2                                                5.0
# 3                                                5.0
# 4                                                5.0
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                5.0
# 1                                                5.0
# 2                                                5.0
# 3                                                5.0
# 4                                                5.0
#
# ...

# %%
advisor8.rename(columns={'Unnamed: 0': 'ชื่อ-สกุล', 'Unnamed: 12': 'ชื่อเรื่อง'}, inplace=True)
advisor8.head(3)
# Out:
#                     ชื่อ-สกุล  \
# 0                         NaN
# 1            tasty-myrtle-ant
# 2  skanky-burgundy-kingfisher
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                5.0
# 1                                                5.0
# 2                                                5.0
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                5.0
# 1                                                5.0
# 2                                                5.0
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# 0                                               10.0
# 1                                                8.0
# 2                                                8.0
#
#   4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)  \
# 0                                     5
# ...

# %% [markdown]
# #### ตรวจสอบค่า missing

# %%
advisor8.isnull().any() #ตรวจสอบค่าสูญหาย
# Out:
# ชื่อ-สกุล                                                                                     True
# 1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ    False
# 2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย                   False
# 3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา                                 False
# 4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)                                                        False
# 5. ความใส่ใจในการจัดพิมพ์เอกสาร เช่น ความถูกต้อง การแก้ไขตามที่ให้ข้อเสนอแนะไปแล้ว           False
# 6. สามารถควบคุมโครงงานให้ดำเนินการเป็นไปตามแผน                                               False
# 7. ความคิดสร้างสรรค์ ความสามารถวางแผนในการทำงาน การแก้ปัญหาในระหว่างการทำงาน                 False
# ความสมบูรณ์ของเล่ม (8.1 การค้นคว้าข้อมูล หรือแสวงหาความรู้เพิ่มเติม)                         False
# ...

# %%
advisor8 = advisor8.fillna(method='ffill')
advisor8.head()
# Out:
#                     ชื่อ-สกุล  \
# 0                         NaN
# 1            tasty-myrtle-ant
# 2  skanky-burgundy-kingfisher
# 3          sleazy-mauve-akita
# 4       crappy-burgundy-quoll
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                5.0
# 1                                                5.0
# 2                                                5.0
# 3                                                5.0
# 4                                                5.0
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                5.0
# 1                                                5.0
# 2                                                5.0
# 3                                                5.0
# 4                                                5.0
#
# ...

# %%
advisor8 = advisor8.dropna(subset=['ชื่อ-สกุล', 'ชื่อเรื่อง'])

# %%
advisor8.isnull().any() #ตรวจสอบค่าสูญหาย
# Out:
# ชื่อ-สกุล                                                                                    False
# 1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ    False
# 2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย                   False
# 3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา                                 False
# 4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)                                                        False
# 5. ความใส่ใจในการจัดพิมพ์เอกสาร เช่น ความถูกต้อง การแก้ไขตามที่ให้ข้อเสนอแนะไปแล้ว           False
# 6. สามารถควบคุมโครงงานให้ดำเนินการเป็นไปตามแผน                                               False
# 7. ความคิดสร้างสรรค์ ความสามารถวางแผนในการทำงาน การแก้ปัญหาในระหว่างการทำงาน                 False
# ความสมบูรณ์ของเล่ม (8.1 การค้นคว้าข้อมูล หรือแสวงหาความรู้เพิ่มเติม)                         False
# ...

# %% [markdown]
# ### advisor9 อ.ธรรณญพร

# %%
advisor9 = pd.read_excel('/content/drive/MyDrive/final/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',sheet_name='อ.ธรรณญพร',skiprows=1)
advisor9.head()
# Out:
#                     Unnamed: 0  \
# 0                          NaN
# 1            chewy-lilac-shark
# 2   greasy-olivine-neanderthal
# 3  hasty-dandelion-grasshopper
# 4           ugly-myrtle-walrus
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
# 3                                                  5
# 4                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
# ...

# %%
advisor9.rename(columns={'Unnamed: 0': 'ชื่อ-สกุล', 'Unnamed: 12': 'ชื่อเรื่อง'}, inplace=True)
advisor9.head(3)
# Out:
#                     ชื่อ-สกุล  \
# 0                         NaN
# 1           chewy-lilac-shark
# 2  greasy-olivine-neanderthal
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# 0                                                 10
# 1                                                  8
# 2                                                  8
#
#    4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)  \
# 0                                      5
# ...

# %% [markdown]
# #### ตรวจสอบค่า missing

# %%
advisor9.isnull().any() #ตรวจสอบค่าสูญหาย
# Out:
# ชื่อ-สกุล                                                                                     True
# 1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ    False
# 2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย                   False
# 3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา                                 False
# 4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)                                                        False
# 5. ความใส่ใจในการจัดพิมพ์เอกสาร เช่น ความถูกต้อง การแก้ไขตามที่ให้ข้อเสนอแนะไปแล้ว           False
# 6. สามารถควบคุมโครงงานให้ดำเนินการเป็นไปตามแผน                                               False
# 7. ความคิดสร้างสรรค์ ความสามารถวางแผนในการทำงาน การแก้ปัญหาในระหว่างการทำงาน                 False
# ความสมบูรณ์ของเล่ม (8.1 การค้นคว้าข้อมูล หรือแสวงหาความรู้เพิ่มเติม)                         False
# ...

# %%
advisor9 = advisor9.fillna(method='ffill')
advisor9.head()
# Out:
#                      ชื่อ-สกุล  \
# 0                          NaN
# 1            chewy-lilac-shark
# 2   greasy-olivine-neanderthal
# 3  hasty-dandelion-grasshopper
# 4           ugly-myrtle-walrus
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
# 3                                                  5
# 4                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
# ...

# %%
advisor9 = advisor9.dropna(subset=['ชื่อ-สกุล', 'ชื่อเรื่อง'])

# %%
advisor9.isnull().any() #ตรวจสอบค่าสูญหาย
# Out:
# ชื่อ-สกุล                                                                                    False
# 1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ    False
# 2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย                   False
# 3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา                                 False
# 4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)                                                        False
# 5. ความใส่ใจในการจัดพิมพ์เอกสาร เช่น ความถูกต้อง การแก้ไขตามที่ให้ข้อเสนอแนะไปแล้ว           False
# 6. สามารถควบคุมโครงงานให้ดำเนินการเป็นไปตามแผน                                               False
# 7. ความคิดสร้างสรรค์ ความสามารถวางแผนในการทำงาน การแก้ปัญหาในระหว่างการทำงาน                 False
# ความสมบูรณ์ของเล่ม (8.1 การค้นคว้าข้อมูล หรือแสวงหาความรู้เพิ่มเติม)                         False
# ...

# %% [markdown]
# ### advisor10 อ.ยุภาพร

# %%
advisor10 = pd.read_excel('/content/drive/MyDrive/final/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',sheet_name='อ.ยุภาพร',skiprows=1)
advisor10.head()
# Out:
#                  Unnamed: 0  \
# 0                       NaN
# 1     nerdy-plum-abyssinian
# 2  gloppy-xanthic-retriever
# 3     cloudy-myrtle-whippet
# 4        cloudy-grey-walrus
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# ...

# %%
advisor10.rename(columns={'Unnamed: 0': 'ชื่อ-สกุล', 'Unnamed: 12': 'ชื่อเรื่อง'}, inplace=True)
advisor10.head(3)
# Out:
#                   ชื่อ-สกุล  \
# 0                       NaN
# 1     nerdy-plum-abyssinian
# 2  gloppy-xanthic-retriever
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# 0                                                 10
# 1                                                 10
# 2                                                 10
#
#    4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)  \
# 0                                      5
# ...

# %% [markdown]
# #### ตรวจสอบค่า missing

# %%
advisor10.isnull().any() #ตรวจสอบค่าสูญหาย
# Out:
# ชื่อ-สกุล                                                                                     True
# 1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ    False
# 2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย                   False
# 3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา                                 False
# 4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)                                                        False
# 5. ความใส่ใจในการจัดพิมพ์เอกสาร เช่น ความถูกต้อง การแก้ไขตามที่ให้ข้อเสนอแนะไปแล้ว           False
# 6. สามารถควบคุมโครงงานให้ดำเนินการเป็นไปตามแผน                                               False
# 7. ความคิดสร้างสรรค์ ความสามารถวางแผนในการทำงาน การแก้ปัญหาในระหว่างการทำงาน                 False
# ความสมบูรณ์ของเล่ม (8.1 การค้นคว้าข้อมูล หรือแสวงหาความรู้เพิ่มเติม)                         False
# ...

# %%
advisor10 = advisor10.fillna(method='ffill')
advisor10.head()
# Out:
#                   ชื่อ-สกุล  \
# 0                       NaN
# 1     nerdy-plum-abyssinian
# 2  gloppy-xanthic-retriever
# 3     cloudy-myrtle-whippet
# 4        cloudy-grey-walrus
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# ...

# %%
advisor10 = advisor10.dropna(subset=['ชื่อ-สกุล', 'ชื่อเรื่อง'])

# %%
advisor10.isnull().any() #ตรวจสอบค่าสูญหาย
# Out:
# ชื่อ-สกุล                                                                                    False
# 1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ    False
# 2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย                   False
# 3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา                                 False
# 4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)                                                        False
# 5. ความใส่ใจในการจัดพิมพ์เอกสาร เช่น ความถูกต้อง การแก้ไขตามที่ให้ข้อเสนอแนะไปแล้ว           False
# 6. สามารถควบคุมโครงงานให้ดำเนินการเป็นไปตามแผน                                               False
# 7. ความคิดสร้างสรรค์ ความสามารถวางแผนในการทำงาน การแก้ปัญหาในระหว่างการทำงาน                 False
# ความสมบูรณ์ของเล่ม (8.1 การค้นคว้าข้อมูล หรือแสวงหาความรู้เพิ่มเติม)                         False
# ...

# %% [markdown]
# ### advisor11 รศ.ธิดาเดียว

# %%
advisor11 = pd.read_excel('/content/drive/MyDrive/final/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',sheet_name='รศ.ธิดาเดียว',skiprows=1)
advisor11.head()
# Out:
#                   Unnamed: 0  \
# 0                        NaN
# 1          paltry-plum-saola
# 2        cloudy-wheat-bobcat
# 3  gloppy-persimmon-flamingo
# 4       sleepy-gamboge-zebra
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# ...

# %%
advisor11.rename(columns={'Unnamed: 0': 'ชื่อ-สกุล', 'Unnamed: 12': 'ชื่อเรื่อง'}, inplace=True)
advisor11.head(3)
# Out:
#              ชื่อ-สกุล  \
# 0                  NaN
# 1    paltry-plum-saola
# 2  cloudy-wheat-bobcat
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# 0                                                 10
# 1                                                  9
# 2                                                  9
#
#    4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)  \
# 0                                      5
# 1                                      5
# ...

# %% [markdown]
# #### ตรวจสอบค่า missing

# %%
advisor11.isnull().any() #ตรวจสอบค่าสูญหาย
# Out:
# ชื่อ-สกุล                                                                                     True
# 1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ    False
# 2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย                   False
# 3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา                                 False
# 4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)                                                        False
# 5. ความใส่ใจในการจัดพิมพ์เอกสาร เช่น ความถูกต้อง การแก้ไขตามที่ให้ข้อเสนอแนะไปแล้ว           False
# 6. สามารถควบคุมโครงงานให้ดำเนินการเป็นไปตามแผน                                               False
# 7. ความคิดสร้างสรรค์ ความสามารถวางแผนในการทำงาน การแก้ปัญหาในระหว่างการทำงาน                 False
# ความสมบูรณ์ของเล่ม (8.1 การค้นคว้าข้อมูล หรือแสวงหาความรู้เพิ่มเติม)                         False
# ...

# %%
advisor11 = advisor11.fillna(method='ffill')
advisor11.head()
# Out:
#                    ชื่อ-สกุล  \
# 0                        NaN
# 1          paltry-plum-saola
# 2        cloudy-wheat-bobcat
# 3  gloppy-persimmon-flamingo
# 4       sleepy-gamboge-zebra
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# ...

# %%
advisor11 = advisor11.dropna(subset=['ชื่อ-สกุล', 'ชื่อเรื่อง'])

# %%
advisor11.isnull().any() #ตรวจสอบค่าสูญหาย
# Out:
# ชื่อ-สกุล                                                                                    False
# 1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ    False
# 2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย                   False
# 3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา                                 False
# 4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)                                                        False
# 5. ความใส่ใจในการจัดพิมพ์เอกสาร เช่น ความถูกต้อง การแก้ไขตามที่ให้ข้อเสนอแนะไปแล้ว           False
# 6. สามารถควบคุมโครงงานให้ดำเนินการเป็นไปตามแผน                                               False
# 7. ความคิดสร้างสรรค์ ความสามารถวางแผนในการทำงาน การแก้ปัญหาในระหว่างการทำงาน                 False
# ความสมบูรณ์ของเล่ม (8.1 การค้นคว้าข้อมูล หรือแสวงหาความรู้เพิ่มเติม)                         False
# ...

# %% [markdown]
# ### advisor12 รศ.สุพรรณี

# %%
advisor12 = pd.read_excel('/content/drive/MyDrive/final/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',sheet_name='รศ.สุพรรณี',skiprows=1)
advisor12.head()
# Out:
#                 Unnamed: 0  \
# 0                      NaN
# 1  chewy-persimmon-catfish
# 2  skanky-amaranth-ostrich
# 3   greasy-eggplant-oyster
# 4         randy-mauve-ibis
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                5.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                5.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# ...

# %%
advisor12.rename(columns={'Unnamed: 0': 'ชื่อ-สกุล', 'Unnamed: 12': 'ชื่อเรื่อง'}, inplace=True)
advisor12.head(3)
# Out:
#                  ชื่อ-สกุล  \
# 0                      NaN
# 1  chewy-persimmon-catfish
# 2  skanky-amaranth-ostrich
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                5.0
# 1                                                NaN
# 2                                                NaN
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                5.0
# 1                                                NaN
# 2                                                NaN
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# 0                                               10.0
# 1                                                NaN
# 2                                                NaN
#
#    4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)  \
# 0                                    5.0
# ...

# %% [markdown]
# #### ตรวจสอบค่า missing

# %%
advisor12.isnull().any() #ตรวจสอบค่าสูญหาย
# Out:
# ชื่อ-สกุล                                                                                     True
# 1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ     True
# 2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย                    True
# 3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา                                  True
# 4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)                                                         True
# 5. ความใส่ใจในการจัดพิมพ์เอกสาร เช่น ความถูกต้อง การแก้ไขตามที่ให้ข้อเสนอแนะไปแล้ว            True
# 6. สามารถควบคุมโครงงานให้ดำเนินการเป็นไปตามแผน                                                True
# 7. ความคิดสร้างสรรค์ ความสามารถวางแผนในการทำงาน การแก้ปัญหาในระหว่างการทำงาน                  True
# ความสมบูรณ์ของเล่ม (8.1 การค้นคว้าข้อมูล หรือแสวงหาความรู้เพิ่มเติม)                          True
# ...

# %%
advisor12 = advisor12.fillna(method='ffill')
advisor12.head()
# Out:
#                  ชื่อ-สกุล  \
# 0                      NaN
# 1  chewy-persimmon-catfish
# 2  skanky-amaranth-ostrich
# 3   greasy-eggplant-oyster
# 4         randy-mauve-ibis
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                5.0
# 1                                                5.0
# 2                                                5.0
# 3                                                5.0
# 4                                                5.0
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                5.0
# 1                                                5.0
# 2                                                5.0
# 3                                                5.0
# 4                                                5.0
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# ...

# %%
advisor12 = advisor12.dropna(subset=['ชื่อ-สกุล', 'ชื่อเรื่อง'])

# %%
advisor12.isnull().any() #ตรวจสอบค่าสูญหาย
# Out:
# ชื่อ-สกุล                                                                                    False
# 1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ    False
# 2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย                   False
# 3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา                                 False
# 4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)                                                        False
# 5. ความใส่ใจในการจัดพิมพ์เอกสาร เช่น ความถูกต้อง การแก้ไขตามที่ให้ข้อเสนอแนะไปแล้ว           False
# 6. สามารถควบคุมโครงงานให้ดำเนินการเป็นไปตามแผน                                               False
# 7. ความคิดสร้างสรรค์ ความสามารถวางแผนในการทำงาน การแก้ปัญหาในระหว่างการทำงาน                 False
# ความสมบูรณ์ของเล่ม (8.1 การค้นคว้าข้อมูล หรือแสวงหาความรู้เพิ่มเติม)                         False
# ...

# %% [markdown]
# # หาคะแนน

# %%
day0_1[['นักศึกษา' ,'กรรมการสอบ','รวม']]
# Out:
#                          นักศึกษา  กรรมการสอบ  รวม
# 1            leaky-rust-chameleon  ผศ.วุฒิชัย   52
# 2              greasy-ruby-bombay  ผศ.วุฒิชัย   50
# 3            leaky-rust-chameleon    อ.ยุภาพร   60
# 4              greasy-ruby-bombay    อ.ยุภาพร   58
# 5             wiggy-silver-drever  ผศ.วุฒิชัย   52
# 6                 stinky-red-chow  ผศ.วุฒิชัย   52
# 7             wiggy-silver-drever    อ.ยุภาพร   48
# 8                 stinky-red-chow    อ.ยุภาพร   48
# 9               paltry-plum-saola  ดร.อุทุมพร   53
# 10            cloudy-wheat-bobcat  ดร.อุทุมพร   53
# 11              paltry-plum-saola   ดร.วรรณพร   56
# 12            cloudy-wheat-bobcat   ดร.วรรณพร   57
# 13      gloppy-persimmon-flamingo  ดร.อุทุมพร   54
# 14           sleepy-gamboge-zebra  ดร.อุทุมพร   51
# 15      gloppy-persimmon-flamingo   ดร.วรรณพร   56
# 16           sleepy-gamboge-zebra   ดร.วรรณพร   54
# 17             sickly-grey-dugong  ดร.อุทุมพร   48
# ...

# %% [markdown]
# ## คะแนนปากเปล่า 60% ชีท 1

# %%
x = day0_1.groupby(['นักศึกษา'])[['รวม']].sum()
x
# Out:
#                                รวม
# นักศึกษา
# boozy-thistle-wildebeest       115
# chewy-persimmon-catfish         95
# chummy-goldenrod-walrus        105
# cloudy-wheat-bobcat            110
# craggy-cream-reindeer          117
# flimsy-lemon-budgerigar        113
# gloppy-persimmon-flamingo      110
# gloppy-xanthic-retriever       105
# greasy-eggplant-oyster          87
# greasy-ruby-bombay             108
# hasty-magnolia-devil           105
# hazy-beige-stoat                86
# jumpy-apricot-frise            117
# leaky-rust-chameleon           112
# lumpy-carmine-slug             120
# nerdy-plum-abyssinian          115
# paltry-plum-saola              109
# randy-gamboge-blue             113
# randy-mauve-ibis                91
# sickly-grey-dugong             101
# skanky-amaranth-ostrich         95
# slaphappy-silver-monkey        101
# sleepy-gamboge-zebra           105
# squirrely-seashell-kingfisher   85
# stinky-red-chow                100
# ...

# %%
x['คะแนนที่ได้'] = ((x['รวม']/140)*0.6)*100
x
# Out:
#                                รวม  คะแนนที่ได้
# นักศึกษา
# boozy-thistle-wildebeest       115    49.285714
# chewy-persimmon-catfish         95    40.714286
# chummy-goldenrod-walrus        105    45.000000
# cloudy-wheat-bobcat            110    47.142857
# craggy-cream-reindeer          117    50.142857
# flimsy-lemon-budgerigar        113    48.428571
# gloppy-persimmon-flamingo      110    47.142857
# gloppy-xanthic-retriever       105    45.000000
# greasy-eggplant-oyster          87    37.285714
# greasy-ruby-bombay             108    46.285714
# hasty-magnolia-devil           105    45.000000
# hazy-beige-stoat                86    36.857143
# jumpy-apricot-frise            117    50.142857
# leaky-rust-chameleon           112    48.000000
# lumpy-carmine-slug             120    51.428571
# nerdy-plum-abyssinian          115    49.285714
# paltry-plum-saola              109    46.714286
# randy-gamboge-blue             113    48.428571
# ...

# %% [markdown]
# ## คะแนนปากเปล่า 60% ชีท 2

# %%
y = day1_1.groupby(['นักศึกษา'])[['รวม']].sum()
y
# Out:
#                              รวม
# นักศึกษา
# bumpy-indigo-dolphin         107
# chewy-lilac-shark            111
# cozy-teal-whale              121
# craggy-mustard-sponge        106
# crappy-burgundy-quoll        118
# flabby-green-fish            122
# freaky-lemon-peccary         121
# fuzzy-silver-discus          106
# geeky-harlequin-duck         118
# gloppy-fuchsia-akbash        121
# greasy-olivine-neanderthal   111
# gummy-olivine-ibis           117
# hasty-dandelion-grasshopper   95
# messy-white-toucan            94
# nippy-lilac-chin              96
# pasty-bronze-booby           107
# randy-rust-lionfish          107
# skanky-burgundy-kingfisher   121
# skimpy-magenta-bombay        121
# skinny-bronze-dormouse       121
# skinny-heliotrope-kudu       125
# sleazy-mauve-akita           117
# snappy-azure-balinese        107
# surly-linen-hyena             96
# tasty-myrtle-ant             123
# ugly-myrtle-walrus            95

# %%
y['คะแนนที่ได้'] = ((y['รวม']/140)*0.6)*100
y
# Out:
#                              รวม  คะแนนที่ได้
# นักศึกษา
# bumpy-indigo-dolphin         107    45.857143
# chewy-lilac-shark            111    47.571429
# cozy-teal-whale              121    51.857143
# craggy-mustard-sponge        106    45.428571
# crappy-burgundy-quoll        118    50.571429
# flabby-green-fish            122    52.285714
# freaky-lemon-peccary         121    51.857143
# fuzzy-silver-discus          106    45.428571
# geeky-harlequin-duck         118    50.571429
# gloppy-fuchsia-akbash        121    51.857143
# greasy-olivine-neanderthal   111    47.571429
# gummy-olivine-ibis           117    50.142857
# hasty-dandelion-grasshopper   95    40.714286
# messy-white-toucan            94    40.285714
# nippy-lilac-chin              96    41.142857
# pasty-bronze-booby           107    45.857143
# randy-rust-lionfish          107    45.857143
# skanky-burgundy-kingfisher   121    51.857143
# skimpy-magenta-bombay        121    51.857143
# ...

# %% [markdown]
# ## คะแนนปากเปล่า 60% ชีท 3

# %%
z = day2_1.groupby(['นักศึกษา'])[['รวม']].sum()
z
# Out:
#                              รวม
# นักศึกษา
# breezy-pear-macaw            112
# chummy-azure-walrus          111
# clammy-zucchini-chicken      121
# cloudy-grey-walrus           120
# cloudy-myrtle-kudu           120
# cloudy-myrtle-whippet        120
# cozy-tangerine-ladybird      104
# craggy-cream-paradise        116
# flabby-asparagus-heron        41
# flaky-sepia-setter           106
# frumpy-gamboge-emu            96
# greasy-tangerine-moorhen     121
# grumpy-flax-bonobo           100
# hazy-aqua-peccary            116
# lousy-corn-mule              102
# lovely-asparagus-urchin      116
# muggy-charcoal-akita         103
# pasty-tomato-okapi           107
# pokey-asparagus-frise        124
# randy-charcoal-flamingo      125
# scaly-pumpkin-monkey         104
# scanty-razzmatazz-rabbit     101
# skanky-copper-affenpinscher   42
# snazzy-auburn-lionfish        97
# stinky-wisteria-nightingale  116
# ugly-harlequin-octopus       116
# whiny-peach-audemer           97

# %%
z['คะแนนที่ได้'] = ((z['รวม']/140)*0.6)*100
z
# Out:
#                              รวม  คะแนนที่ได้
# นักศึกษา
# breezy-pear-macaw            112    48.000000
# chummy-azure-walrus          111    47.571429
# clammy-zucchini-chicken      121    51.857143
# cloudy-grey-walrus           120    51.428571
# cloudy-myrtle-kudu           120    51.428571
# cloudy-myrtle-whippet        120    51.428571
# cozy-tangerine-ladybird      104    44.571429
# craggy-cream-paradise        116    49.714286
# flabby-asparagus-heron        41    17.571429
# flaky-sepia-setter           106    45.428571
# frumpy-gamboge-emu            96    41.142857
# greasy-tangerine-moorhen     121    51.857143
# grumpy-flax-bonobo           100    42.857143
# hazy-aqua-peccary            116    49.714286
# lousy-corn-mule              102    43.714286
# lovely-asparagus-urchin      116    49.714286
# muggy-charcoal-akita         103    44.142857
# pasty-tomato-okapi           107    45.857143
# pokey-asparagus-frise        124    53.142857
# ...

# %% [markdown]
# ## คะแนน advisor1 ดร.ธนพงศ์

# %%
advisor1
# Out:
#                   ชื่อ-สกุล  \
# 1       jumpy-apricot-frise
# 2  boozy-thistle-wildebeest
# 3      hasty-magnolia-devil
# 4   chummy-goldenrod-walrus
# 5        randy-gamboge-blue
# 6   flimsy-lemon-budgerigar
# 7     skimpy-magenta-bombay
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 1                                                  5
# 2                                                  4
# 3                                                  5
# 4                                                  5
# 5                                                  4
# 6                                                  4
# 7                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 1                                                  5
# 2                                                  4
# 3                                                  5
# ...

# %%
a = advisor1[['ชื่อ-สกุล' ,'รวม']]
a
# Out:
#                   ชื่อ-สกุล  รวม
# 1       jumpy-apricot-frise   67
# 2  boozy-thistle-wildebeest   64
# 3      hasty-magnolia-devil   67
# 4   chummy-goldenrod-walrus   67
# 5        randy-gamboge-blue   61
# 6   flimsy-lemon-budgerigar   64
# 7     skimpy-magenta-bombay   70

# %%
a['คะแนนที่ได้'] = ((a['รวม']/70)*0.4)*100
a
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                   ชื่อ-สกุล  รวม  คะแนนที่ได้
# 1       jumpy-apricot-frise   67    38.285714
# 2  boozy-thistle-wildebeest   64    36.571429
# 3      hasty-magnolia-devil   67    38.285714
# 4   chummy-goldenrod-walrus   67    38.285714
# 5        randy-gamboge-blue   61    34.857143
# 6   flimsy-lemon-budgerigar   64    36.571429
# 7     skimpy-magenta-bombay   70    40.000000

# %% [markdown]
# ## คะแนน advisor2 ดร.ธิปไตย

# %%
b = advisor2[['ชื่อ-สกุล' ,'รวม']]
b
# Out:
#               ชื่อ-สกุล  รวม
# 1  leaky-rust-chameleon   68
# 2    greasy-ruby-bombay   61
# 3   wiggy-silver-drever   67
# 4       stinky-red-chow   67
# 5  bumpy-indigo-dolphin   67
# 6   randy-rust-lionfish   60
# 7    flaky-sepia-setter   69
# 8    pasty-tomato-okapi   69

# %%
b['คะแนนที่ได้'] = ((b['รวม']/70)*0.4)*100
b
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#               ชื่อ-สกุล  รวม  คะแนนที่ได้
# 1  leaky-rust-chameleon   68    38.857143
# 2    greasy-ruby-bombay   61    34.857143
# 3   wiggy-silver-drever   67    38.285714
# 4       stinky-red-chow   67    38.285714
# 5  bumpy-indigo-dolphin   67    38.285714
# 6   randy-rust-lionfish   60    34.285714
# 7    flaky-sepia-setter   69    39.428571
# 8    pasty-tomato-okapi   69    39.428571

# %% [markdown]
# ## คะแนน advisor3 ดร.พลากร

# %%
c = advisor3[['ชื่อ-สกุล' ,'รวม']]
c
# Out:
#                      ชื่อ-สกุล  รวม
# 1        craggy-mustard-sponge   55
# 2          fuzzy-silver-discus   55
# 3              lousy-corn-mule   64
# 4         muggy-charcoal-akita   64
# 5  stinky-wisteria-nightingale   66
# 6            hazy-aqua-peccary   65

# %%
c['คะแนนที่ได้'] = ((c['รวม']/70)*0.4)*100
c
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                      ชื่อ-สกุล  รวม  คะแนนที่ได้
# 1        craggy-mustard-sponge   55    31.428571
# 2          fuzzy-silver-discus   55    31.428571
# 3              lousy-corn-mule   64    36.571429
# 4         muggy-charcoal-akita   64    36.571429
# 5  stinky-wisteria-nightingale   66    37.714286
# 6            hazy-aqua-peccary   65    37.142857

# %% [markdown]
# ## คะแนน advisor4 ดร.วรรณพร

# %%
d = advisor4[['ชื่อ-สกุล' ,'รวม']]
d
# Out:
#                 ชื่อ-สกุล        รวม
# 1  skinny-bronze-dormouse  64.000000
# 2    freaky-lemon-peccary  62.000000
# 3       flabby-green-fish  66.000000
# 4  skinny-heliotrope-kudu  68.000000
# 5      messy-white-toucan  61.384615

# %%
d['คะแนนที่ได้'] = ((d['รวม']/70)*0.4)*100
d
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                 ชื่อ-สกุล        รวม  คะแนนที่ได้
# 1  skinny-bronze-dormouse  64.000000    36.571429
# 2    freaky-lemon-peccary  62.000000    35.428571
# 3       flabby-green-fish  66.000000    37.714286
# 4  skinny-heliotrope-kudu  68.000000    38.857143
# 5      messy-white-toucan  61.384615    35.076923

# %% [markdown]
# ## คะแนน advisor5 ดร.อุทุมพร

# %%
e = advisor5[['ชื่อ-สกุล' ,'รวม']]
e
# Out:
#                   ชื่อ-สกุล  รวม
# 1       chummy-azure-walrus   68
# 2         breezy-pear-macaw   69
# 3   cozy-tangerine-ladybird   62
# 4      scaly-pumpkin-monkey   62
# 5  scanty-razzmatazz-rabbit   65
# 6        grumpy-flax-bonobo   65

# %%
e['คะแนนที่ได้'] = ((e['รวม']/70)*0.4)*100
e
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                   ชื่อ-สกุล  รวม  คะแนนที่ได้
# 1       chummy-azure-walrus   68    38.857143
# 2         breezy-pear-macaw   69    39.428571
# 3   cozy-tangerine-ladybird   62    35.428571
# 4      scaly-pumpkin-monkey   62    35.428571
# 5  scanty-razzmatazz-rabbit   65    37.142857
# 6        grumpy-flax-bonobo   65    37.142857

# %% [markdown]
# ## คะแนน advisor6 ผศ.วุฒิชัย

# %%
f = advisor6[['ชื่อ-สกุล' ,'รวม']]
f
# Out:
#                  ชื่อ-สกุล  รวม
# 1       lumpy-carmine-slug   70
# 2    snappy-azure-balinese   65
# 3       pasty-bronze-booby   65
# 4    pokey-asparagus-frise   64
# 5  randy-charcoal-flamingo   64

# %%
f['คะแนนที่ได้'] = ((f['รวม']/70)*0.4)*100
f
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                  ชื่อ-สกุล  รวม  คะแนนที่ได้
# 1       lumpy-carmine-slug   70    40.000000
# 2    snappy-azure-balinese   65    37.142857
# 3       pasty-bronze-booby   65    37.142857
# 4    pokey-asparagus-frise   64    36.571429
# 5  randy-charcoal-flamingo   64    36.571429

# %% [markdown]
# ## คะแนน advisor7 ผศ.สุกัญญา

# %%
g = advisor7[['ชื่อ-สกุล' ,'รวม']]
g
# Out:
#                   ชื่อ-สกุล  รวม
# 1          whiny-pear-otter   63
# 2     craggy-cream-reindeer   63
# 3        cloudy-myrtle-kudu   66
# 4   lovely-asparagus-urchin   66
# 5   clammy-zucchini-chicken   63
# 6  greasy-tangerine-moorhen   63

# %%
g['คะแนนที่ได้'] = ((g['รวม']/70)*0.4)*100
g
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                   ชื่อ-สกุล  รวม  คะแนนที่ได้
# 1          whiny-pear-otter   63    36.000000
# 2     craggy-cream-reindeer   63    36.000000
# 3        cloudy-myrtle-kudu   66    37.714286
# 4   lovely-asparagus-urchin   66    37.714286
# 5   clammy-zucchini-chicken   63    36.000000
# 6  greasy-tangerine-moorhen   63    36.000000

# %% [markdown]
# ## คะแนน advisor8 รศ.วิชุดา

# %%
h = advisor8[['ชื่อ-สกุล' ,'รวม']]
h
# Out:
#                     ชื่อ-สกุล        รวม
# 1            tasty-myrtle-ant  61.000000
# 2  skanky-burgundy-kingfisher  61.000000
# 3          sleazy-mauve-akita  61.000000
# 4       crappy-burgundy-quoll  62.000000
# 5        geeky-harlequin-duck  62.000000
# 6          gummy-olivine-ibis  61.000000
# 7          frumpy-gamboge-emu  45.230769
# 8      ugly-harlequin-octopus  57.500000
# 9       craggy-cream-paradise  57.000000

# %%
h['คะแนนที่ได้'] = ((h['รวม']/70)*0.4)*100
h
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                     ชื่อ-สกุล        รวม  คะแนนที่ได้
# 1            tasty-myrtle-ant  61.000000    34.857143
# 2  skanky-burgundy-kingfisher  61.000000    34.857143
# 3          sleazy-mauve-akita  61.000000    34.857143
# 4       crappy-burgundy-quoll  62.000000    35.428571
# 5        geeky-harlequin-duck  62.000000    35.428571
# 6          gummy-olivine-ibis  61.000000    34.857143
# 7          frumpy-gamboge-emu  45.230769    25.846154
# 8      ugly-harlequin-octopus  57.500000    32.857143
# 9       craggy-cream-paradise  57.000000    32.571429

# %% [markdown]
# ## คะแนน advisor9 อ.ธรรณญพร

# %%
i = advisor9[['ชื่อ-สกุล' ,'รวม']]
i
# Out:
#                      ชื่อ-สกุล  รวม
# 1            chewy-lilac-shark   61
# 2   greasy-olivine-neanderthal   60
# 3  hasty-dandelion-grasshopper   62
# 4           ugly-myrtle-walrus   62
# 5        gloppy-fuchsia-akbash   66
# 6              cozy-teal-whale   66
# 7       flabby-asparagus-heron   52
# 8  skanky-copper-affenpinscher   55

# %%
i['คะแนนที่ได้'] = ((i['รวม']/70)*0.4)*100
i
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                      ชื่อ-สกุล  รวม  คะแนนที่ได้
# 1            chewy-lilac-shark   61    34.857143
# 2   greasy-olivine-neanderthal   60    34.285714
# 3  hasty-dandelion-grasshopper   62    35.428571
# 4           ugly-myrtle-walrus   62    35.428571
# 5        gloppy-fuchsia-akbash   66    37.714286
# 6              cozy-teal-whale   66    37.714286
# 7       flabby-asparagus-heron   52    29.714286
# 8  skanky-copper-affenpinscher   55    31.428571

# %% [markdown]
# ## คะแนน advisor10 อ.ยุภาพร

# %%
j = advisor10[['ชื่อ-สกุล' ,'รวม']]
j
# Out:
#                   ชื่อ-สกุล  รวม
# 1     nerdy-plum-abyssinian   67
# 2  gloppy-xanthic-retriever   67
# 3     cloudy-myrtle-whippet   67
# 4        cloudy-grey-walrus   67
# 5    snazzy-auburn-lionfish   67
# 6       whiny-peach-audemer   67

# %%
j['คะแนนที่ได้'] = ((j['รวม']/70)*0.4)*100
j
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                   ชื่อ-สกุล  รวม  คะแนนที่ได้
# 1     nerdy-plum-abyssinian   67    38.285714
# 2  gloppy-xanthic-retriever   67    38.285714
# 3     cloudy-myrtle-whippet   67    38.285714
# 4        cloudy-grey-walrus   67    38.285714
# 5    snazzy-auburn-lionfish   67    38.285714
# 6       whiny-peach-audemer   67    38.285714

# %% [markdown]
# ## คะแนน advisor11 รศ.ธิดาเดียว

# %%
k = advisor11[['ชื่อ-สกุล' ,'รวม']]
k
# Out:
#                    ชื่อ-สกุล  รวม
# 1          paltry-plum-saola   66
# 2        cloudy-wheat-bobcat   66
# 3  gloppy-persimmon-flamingo   65
# 4       sleepy-gamboge-zebra   65
# 5         sickly-grey-dugong   65
# 6    slaphappy-silver-monkey   65

# %%
k['คะแนนที่ได้'] = ((k['รวม']/70)*0.4)*100
k
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                    ชื่อ-สกุล  รวม  คะแนนที่ได้
# 1          paltry-plum-saola   66    37.714286
# 2        cloudy-wheat-bobcat   66    37.714286
# 3  gloppy-persimmon-flamingo   65    37.142857
# 4       sleepy-gamboge-zebra   65    37.142857
# 5         sickly-grey-dugong   65    37.142857
# 6    slaphappy-silver-monkey   65    37.142857

# %% [markdown]
# ## คะแนน advisor12 รศ.สุพรรณี

# %%
l = advisor12[['ชื่อ-สกุล' ,'รวม']]
l
# Out:
#                        ชื่อ-สกุล  รวม
# 1        chewy-persimmon-catfish   62
# 2        skanky-amaranth-ostrich   55
# 3         greasy-eggplant-oyster   50
# 4               randy-mauve-ibis   63
# 5               hazy-beige-stoat   50
# 6  squirrely-seashell-kingfisher   50
# 7              surly-linen-hyena   50
# 8               nippy-lilac-chin   62

# %%
l['คะแนนที่ได้'] = ((l['รวม']/70)*0.4)*100
l
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                        ชื่อ-สกุล  รวม  คะแนนที่ได้
# 1        chewy-persimmon-catfish   62    35.428571
# 2        skanky-amaranth-ostrich   55    31.428571
# 3         greasy-eggplant-oyster   50    28.571429
# 4               randy-mauve-ibis   63    36.000000
# 5               hazy-beige-stoat   50    28.571429
# 6  squirrely-seashell-kingfisher   50    28.571429
# 7              surly-linen-hyena   50    28.571429
# 8               nippy-lilac-chin   62    35.428571

# %% [markdown]
# # รวมตาราง คะแนนปากเปล่า

# %% [markdown]
# ## รวมตาราง x,y

# %%
x.shape
# Out:
# (27, 2)

# %%
y.shape
# Out:
# (26, 2)

# %%
xy = pd.concat([x, y])
xy.shape
# Out:
# (53, 2)

# %%
xy
# Out:
#                                รวม  คะแนนที่ได้
# นักศึกษา
# boozy-thistle-wildebeest       115    49.285714
# chewy-persimmon-catfish         95    40.714286
# chummy-goldenrod-walrus        105    45.000000
# cloudy-wheat-bobcat            110    47.142857
# craggy-cream-reindeer          117    50.142857
# flimsy-lemon-budgerigar        113    48.428571
# gloppy-persimmon-flamingo      110    47.142857
# gloppy-xanthic-retriever       105    45.000000
# greasy-eggplant-oyster          87    37.285714
# greasy-ruby-bombay             108    46.285714
# hasty-magnolia-devil           105    45.000000
# hazy-beige-stoat                86    36.857143
# jumpy-apricot-frise            117    50.142857
# leaky-rust-chameleon           112    48.000000
# lumpy-carmine-slug             120    51.428571
# nerdy-plum-abyssinian          115    49.285714
# paltry-plum-saola              109    46.714286
# randy-gamboge-blue             113    48.428571
# ...

# %% [markdown]
# ## รวมตาราง xy กับ z

# %%
z.shape
# Out:
# (27, 2)

# %%
xyz = pd.concat([xy, z])
xyz.shape
# Out:
# (80, 2)

# %%
xyz
# Out:
#                              รวม  คะแนนที่ได้
# นักศึกษา
# boozy-thistle-wildebeest     115    49.285714
# chewy-persimmon-catfish       95    40.714286
# chummy-goldenrod-walrus      105    45.000000
# cloudy-wheat-bobcat          110    47.142857
# craggy-cream-reindeer        117    50.142857
# ...                          ...          ...
# skanky-copper-affenpinscher   42    18.000000
# snazzy-auburn-lionfish        97    41.571429
# stinky-wisteria-nightingale  116    49.714286
# ugly-harlequin-octopus       116    49.714286
# whiny-peach-audemer           97    41.571429
#
# [80 rows x 2 columns]

# %% [markdown]
# # รวมตารางคะแนนอาจารย์ที่ปรึกษา

# %% [markdown]
# ## ตาราง a กับ b

# %%
a.shape
# Out:
# (7, 3)

# %%
b.shape
# Out:
# (8, 3)

# %%
ab = pd.concat([a, b])
ab.shape
# Out:
# (15, 3)

# %%
ab
# Out:
#                   ชื่อ-สกุล  รวม  คะแนนที่ได้
# 1       jumpy-apricot-frise   67    38.285714
# 2  boozy-thistle-wildebeest   64    36.571429
# 3      hasty-magnolia-devil   67    38.285714
# 4   chummy-goldenrod-walrus   67    38.285714
# 5        randy-gamboge-blue   61    34.857143
# 6   flimsy-lemon-budgerigar   64    36.571429
# 7     skimpy-magenta-bombay   70    40.000000
# 1      leaky-rust-chameleon   68    38.857143
# 2        greasy-ruby-bombay   61    34.857143
# 3       wiggy-silver-drever   67    38.285714
# 4           stinky-red-chow   67    38.285714
# 5      bumpy-indigo-dolphin   67    38.285714
# 6       randy-rust-lionfish   60    34.285714
# 7        flaky-sepia-setter   69    39.428571
# 8        pasty-tomato-okapi   69    39.428571

# %% [markdown]
# ## ตาราง ab กับ c

# %%
ab.shape
# Out:
# (15, 3)

# %%
c.shape
# Out:
# (6, 3)

# %%
abc = pd.concat([ab, c])
abc.shape
# Out:
# (21, 3)

# %% [markdown]
# ## ตาราง abc กับ d

# %%
d.shape
# Out:
# (5, 3)

# %%
abcd = pd.concat([abc, d])
abcd.shape
# Out:
# (26, 3)

# %% [markdown]
# ## ตาราง abcd กับ e

# %%
e.shape
# Out:
# (6, 3)

# %%
abcde = pd.concat([abcd, e])
abcde.shape
# Out:
# (32, 3)

# %% [markdown]
# ## ตาราง abcde กับ f

# %%
f.shape
# Out:
# (5, 3)

# %%
abcdef = pd.concat([abcde, f])
abcdef.shape
# Out:
# (37, 3)

# %% [markdown]
# ## ตาราง abcdef กับ g

# %%
g.shape
# Out:
# (6, 3)

# %%
abcdefg = pd.concat([abcdef, g])
abcdefg.shape
# Out:
# (43, 3)

# %% [markdown]
# ## ตาราง abcdefg กับ h

# %%
h.shape
# Out:
# (9, 3)

# %%
abcdefgh = pd.concat([abcdefg, h])
abcdefgh.shape
# Out:
# (52, 3)

# %% [markdown]
# ## ตาราง abcdefgh กับ i

# %%
i.shape
# Out:
# (8, 3)

# %%
abcdefghi = pd.concat([abcdefgh, i])
abcdefghi.shape
# Out:
# (60, 3)

# %% [markdown]
# ## ตาราง abcdefghi กับ j

# %%
j.shape
# Out:
# (6, 3)

# %%
abcdefghij = pd.concat([abcdefghi, j])
abcdefghij.shape
# Out:
# (66, 3)

# %% [markdown]
# ## ตาราง abcdefghij กับ k กับ l

# %%
k.shape
# Out:
# (6, 3)

# %%
abcdefghijkl = pd.concat([abcdefghij, k, l])
abcdefghijkl.shape
# Out:
# (80, 3)

# %% [markdown]
# # เอาตาราง xyz รวมกับตาราง abcdefghijkl

# %%
xyz
# Out:
#                              รวม  คะแนนที่ได้
# นักศึกษา
# boozy-thistle-wildebeest     115    49.285714
# chewy-persimmon-catfish       95    40.714286
# chummy-goldenrod-walrus      105    45.000000
# cloudy-wheat-bobcat          110    47.142857
# craggy-cream-reindeer        117    50.142857
# ...                          ...          ...
# skanky-copper-affenpinscher   42    18.000000
# snazzy-auburn-lionfish        97    41.571429
# stinky-wisteria-nightingale  116    49.714286
# ugly-harlequin-octopus       116    49.714286
# whiny-peach-audemer           97    41.571429
#
# [80 rows x 2 columns]

# %%
abcdefghijkl.rename(columns={'ชื่อ-สกุล': 'นักศึกษา'}, inplace=True)
abcdefghijkl.head(3)
# Out:
#                    นักศึกษา   รวม  คะแนนที่ได้
# 1       jumpy-apricot-frise  67.0    38.285714
# 2  boozy-thistle-wildebeest  64.0    36.571429
# 3      hasty-magnolia-devil  67.0    38.285714

# %%
abcdefghijkl
# Out:
#                          นักศึกษา   รวม  คะแนนที่ได้
# 1             jumpy-apricot-frise  67.0    38.285714
# 2        boozy-thistle-wildebeest  64.0    36.571429
# 3            hasty-magnolia-devil  67.0    38.285714
# 4         chummy-goldenrod-walrus  67.0    38.285714
# 5              randy-gamboge-blue  61.0    34.857143
# ..                            ...   ...          ...
# 4                randy-mauve-ibis  63.0    36.000000
# 5                hazy-beige-stoat  50.0    28.571429
# 6   squirrely-seashell-kingfisher  50.0    28.571429
# 7               surly-linen-hyena  50.0    28.571429
# 8                nippy-lilac-chin  62.0    35.428571
#
# [80 rows x 3 columns]

# %%
# รวมตาราง อิงไฟล์ทางซ้ายมือเป็นหลัก
table_merge = xyz.merge(abcdefghijkl, how ='left', left_on='นักศึกษา',right_on='นักศึกษา') 
table_merge
# Out:
#                        นักศึกษา  รวม_x  คะแนนที่ได้_x  รวม_y  คะแนนที่ได้_y
# 0      boozy-thistle-wildebeest    115      49.285714   64.0      36.571429
# 1       chewy-persimmon-catfish     95      40.714286   62.0      35.428571
# 2       chummy-goldenrod-walrus    105      45.000000   67.0      38.285714
# 3           cloudy-wheat-bobcat    110      47.142857   66.0      37.714286
# 4         craggy-cream-reindeer    117      50.142857   63.0      36.000000
# ..                          ...    ...            ...    ...            ...
# 75  skanky-copper-affenpinscher     42      18.000000   55.0      31.428571
# 76       snazzy-auburn-lionfish     97      41.571429   67.0      38.285714
# 77  stinky-wisteria-nightingale    116      49.714286   66.0      37.714286
# 78       ugly-harlequin-octopus    116      49.714286   57.5      32.857143
# 79          whiny-peach-audemer     97      41.571429   67.0      38.285714
#
# [80 rows x 5 columns]

# %%
#เปลี่ยนชื่อ columns
table_merge.rename(columns={'รวม_x': 'คะแนนรวมสอบปากเปล่า', 'คะแนนที่ได้_x': 'คะแนนสอบปากเปล่าคิดเป็น 60%','รวม_y': 'คะแนนรวมอาจารย์ที่ปรึกษา','คะแนนที่ได้_y': 'คะแนนอาจารย์ที่ปรึกษาคิดเป็น 40%'}, inplace=True)
table_merge.head()
# Out:
#                    นักศึกษา  คะแนนรวมสอบปากเปล่า  คะแนนสอบปากเปล่าคิดเป็น 60%  \
# 0  boozy-thistle-wildebeest                  115                    49.285714
# 1   chewy-persimmon-catfish                   95                    40.714286
# 2   chummy-goldenrod-walrus                  105                    45.000000
# 3       cloudy-wheat-bobcat                  110                    47.142857
# 4     craggy-cream-reindeer                  117                    50.142857
#
#    คะแนนรวมอาจารย์ที่ปรึกษา  คะแนนอาจารย์ที่ปรึกษาคิดเป็น 40%
# 0                      64.0                         36.571429
# 1                      62.0                         35.428571
# 2                      67.0                         38.285714
# 3                      66.0                         37.714286
# 4                      63.0                         36.000000

# %%
table_merge['scores 100%'] = table_merge['คะแนนสอบปากเปล่าคิดเป็น 60%']+table_merge['คะแนนอาจารย์ที่ปรึกษาคิดเป็น 40%']
table_merge
# Out:
#                        นักศึกษา  คะแนนรวมสอบปากเปล่า  \
# 0      boozy-thistle-wildebeest                  115
# 1       chewy-persimmon-catfish                   95
# 2       chummy-goldenrod-walrus                  105
# 3           cloudy-wheat-bobcat                  110
# 4         craggy-cream-reindeer                  117
# ..                          ...                  ...
# 75  skanky-copper-affenpinscher                   42
# 76       snazzy-auburn-lionfish                   97
# 77  stinky-wisteria-nightingale                  116
# 78       ugly-harlequin-octopus                  116
# 79          whiny-peach-audemer                   97
#
#     คะแนนสอบปากเปล่าคิดเป็น 60%  คะแนนรวมอาจารย์ที่ปรึกษา  \
# 0                     49.285714                      64.0
# 1                     40.714286                      62.0
# 2                     45.000000                      67.0
# 3                     47.142857                      66.0
# ...

# %%
A = table_merge[table_merge['scores 100%']>=80]
A.insert(1, "Grade", "A")
A.head()
# Out:
#                    นักศึกษา Grade  คะแนนรวมสอบปากเปล่า  \
# 0  boozy-thistle-wildebeest     A                  115
# 2   chummy-goldenrod-walrus     A                  105
# 3       cloudy-wheat-bobcat     A                  110
# 4     craggy-cream-reindeer     A                  117
# 5   flimsy-lemon-budgerigar     A                  113
#
#    คะแนนสอบปากเปล่าคิดเป็น 60%  คะแนนรวมอาจารย์ที่ปรึกษา  \
# 0                    49.285714                      64.0
# 2                    45.000000                      67.0
# 3                    47.142857                      66.0
# 4                    50.142857                      63.0
# 5                    48.428571                      64.0
#
#    คะแนนอาจารย์ที่ปรึกษาคิดเป็น 40%  คะแนนรวม 100%  scores 100%
# 0                         36.571429      85.857143    85.857143
# 2                         38.285714      83.285714    83.285714
# 3                         37.714286      84.857143    84.857143
# ...

# %%
Bplus = table_merge[(table_merge['scores 100%']>=75)&(table_merge['scores 100%']<=79)]
Bplus.insert(1, "Grade", "B+")
Bplus
# Out:
#                        นักศึกษา Grade  คะแนนรวมสอบปากเปล่า  \
# 1       chewy-persimmon-catfish    B+                   95
# 18             randy-mauve-ibis    B+                   91
# 30        craggy-mustard-sponge    B+                  106
# 34          fuzzy-silver-discus    B+                  106
# 39  hasty-dandelion-grasshopper    B+                   95
# 40           messy-white-toucan    B+                   94
# 41             nippy-lilac-chin    B+                   96
# 52           ugly-myrtle-walrus    B+                   95
#
#     คะแนนสอบปากเปล่าคิดเป็น 60%  คะแนนรวมอาจารย์ที่ปรึกษา  \
# 1                     40.714286                 62.000000
# 18                    39.000000                 63.000000
# 30                    45.428571                 55.000000
# 34                    45.428571                 55.000000
# 39                    40.714286                 62.000000
# 40                    40.285714                 61.384615
# ...

# %%
B=table_merge[(table_merge['scores 100%']>=70)&(table_merge['scores 100%']<=74)]
B.insert(1, "Grade", "B")
B
# Out:
#                    นักศึกษา Grade  คะแนนรวมสอบปากเปล่า  \
# 20  skanky-amaranth-ostrich     B                   95
#
#     คะแนนสอบปากเปล่าคิดเป็น 60%  คะแนนรวมอาจารย์ที่ปรึกษา  \
# 20                    40.714286                      55.0
#
#     คะแนนอาจารย์ที่ปรึกษาคิดเป็น 40%  คะแนนรวม 100%  scores 100%
# 20                         31.428571      72.142857    72.142857

# %%
Cplus=table_merge[(table_merge['scores 100%']>=65)&(table_merge['scores 100%']<=69)]
Cplus.insert(1, "Grade", "C+")
Cplus
# Out:
#                          นักศึกษา Grade  คะแนนรวมสอบปากเปล่า  \
# 8          greasy-eggplant-oyster    C+                   87
# 11               hazy-beige-stoat    C+                   86
# 23  squirrely-seashell-kingfisher    C+                   85
# 63             frumpy-gamboge-emu    C+                   96
#
#     คะแนนสอบปากเปล่าคิดเป็น 60%  คะแนนรวมอาจารย์ที่ปรึกษา  \
# 8                     37.285714                 50.000000
# 11                    36.857143                 50.000000
# 23                    36.428571                 50.000000
# 63                    41.142857                 45.230769
#
#     คะแนนอาจารย์ที่ปรึกษาคิดเป็น 40%  คะแนนรวม 100%  scores 100%
# 8                          28.571429      65.857143    65.857143
# 11                         28.571429      65.428571    65.428571
# 23                         28.571429      65.000000    65.000000
# 63                         25.846154      66.989011    66.989011

# %%
C=table_merge[(table_merge['scores 100%']>=60)&(table_merge['scores 100%']<=64)]
C.insert(1, "Grade", "C")
C
# Out:
# Empty DataFrame
# Columns: [นักศึกษา, Grade, คะแนนรวมสอบปากเปล่า, คะแนนสอบปากเปล่าคิดเป็น 60%, คะแนนรวมอาจารย์ที่ปรึกษา, คะแนนอาจารย์ที่ปรึกษาคิดเป็น 40%, คะแนนรวม 100%, scores 100%]
# Index: []

# %%
Dplus=table_merge[(table_merge['scores 100%']>=55)&(table_merge['scores 100%']<=59)]
Dplus.insert(1, "Grade", "D+")
Dplus
# Out:
# Empty DataFrame
# Columns: [นักศึกษา, Grade, คะแนนรวมสอบปากเปล่า, คะแนนสอบปากเปล่าคิดเป็น 60%, คะแนนรวมอาจารย์ที่ปรึกษา, คะแนนอาจารย์ที่ปรึกษาคิดเป็น 40%, คะแนนรวม 100%, scores 100%]
# Index: []

# %%
D = table_merge[(table_merge['scores 100%']>=50)&(table_merge['scores 100%']<=54)]
D.insert(1, "Grade", "D")
D
# Out:
# Empty DataFrame
# Columns: [นักศึกษา, Grade, คะแนนรวมสอบปากเปล่า, คะแนนสอบปากเปล่าคิดเป็น 60%, คะแนนรวมอาจารย์ที่ปรึกษา, คะแนนอาจารย์ที่ปรึกษาคิดเป็น 40%, คะแนนรวม 100%, scores 100%]
# Index: []

# %%
F=table_merge[table_merge['scores 100%']<50]
F.insert(1, "Grade", "F")
F
# Out:
#                        นักศึกษา Grade  คะแนนรวมสอบปากเปล่า  \
# 61       flabby-asparagus-heron     F                   41
# 75  skanky-copper-affenpinscher     F                   42
#
#     คะแนนสอบปากเปล่าคิดเป็น 60%  คะแนนรวมอาจารย์ที่ปรึกษา  \
# 61                    17.571429                      52.0
# 75                    18.000000                      55.0
#
#     คะแนนอาจารย์ที่ปรึกษาคิดเป็น 40%  คะแนนรวม 100%  scores 100%
# 61                         29.714286      47.285714    47.285714
# 75                         31.428571      49.428571    49.428571

# %% [markdown]
# # 1). รวมคะแนนและตัดเกรดแบบ อิงเกณฑ์ <50 ได้ F ... >= 80 ได้ A และ save ตาราง ชื่อ คะแนนรวมและเกรดที่ได้ของนักศึกษาแต่ละคน

# %%
Grade = pd.concat([A,Bplus,B,Cplus,F]) #รวมเกรด
Grade
# Out:
#                          นักศึกษา Grade  คะแนนรวมสอบปากเปล่า  \
# 0        boozy-thistle-wildebeest     A                  115
# 2         chummy-goldenrod-walrus     A                  105
# 3             cloudy-wheat-bobcat     A                  110
# 4           craggy-cream-reindeer     A                  117
# 5         flimsy-lemon-budgerigar     A                  113
# ..                            ...   ...                  ...
# 11               hazy-beige-stoat    C+                   86
# 23  squirrely-seashell-kingfisher    C+                   85
# 63             frumpy-gamboge-emu    C+                   96
# 61         flabby-asparagus-heron     F                   41
# 75    skanky-copper-affenpinscher     F                   42
#
#     คะแนนสอบปากเปล่าคิดเป็น 60%  คะแนนรวมอาจารย์ที่ปรึกษา  \
# 0                     49.285714                 64.000000
# 2                     45.000000                 67.000000
# ...

# %%
Grade_final = Grade[['นักศึกษา' ,'Grade','scores 100%']]
Grade_final
# Out:
#                          นักศึกษา Grade  scores 100%
# 0        boozy-thistle-wildebeest     A    85.857143
# 2         chummy-goldenrod-walrus     A    83.285714
# 3             cloudy-wheat-bobcat     A    84.857143
# 4           craggy-cream-reindeer     A    86.142857
# 5         flimsy-lemon-budgerigar     A    85.000000
# ..                            ...   ...          ...
# 11               hazy-beige-stoat    C+    65.428571
# 23  squirrely-seashell-kingfisher    C+    65.000000
# 63             frumpy-gamboge-emu    C+    66.989011
# 61         flabby-asparagus-heron     F    47.285714
# 75    skanky-copper-affenpinscher     F    49.428571
#
# [77 rows x 3 columns]

# %% [markdown]
# save table

# %%
Grade_final.to_csv('Grade_final.csv', index=False)

# %% [markdown]
# #2).Stacked Barchart แสดงคะแนนรวมของนักศึกษาแต่ละคนโดยเรียงจากคะแนนรวมมากที่สุดไปน้อยที่สุด (คะแนนส่วนที่ปรึกษา ซ้อนกับ คะแนนสอบปากเปล่า)

# %%
aa= table_merge.sort_values(by='คะแนนอาจารย์ที่ปรึกษาคิดเป็น 40%',ascending=False) #มากไปน้อย
aa
# Out:
#                          นักศึกษา  คะแนนรวมสอบปากเปล่า  \
# 45          skimpy-magenta-bombay                  121
# 14             lumpy-carmine-slug                  120
# 53              breezy-pear-macaw                  112
# 62             flaky-sepia-setter                  106
# 70             pasty-tomato-okapi                  107
# ..                            ...                  ...
# 23  squirrely-seashell-kingfisher                   85
# 11               hazy-beige-stoat                   86
# 8          greasy-eggplant-oyster                   87
# 50              surly-linen-hyena                   96
# 63             frumpy-gamboge-emu                   96
#
#     คะแนนสอบปากเปล่าคิดเป็น 60%  คะแนนรวมอาจารย์ที่ปรึกษา  \
# 45                    51.857143                 70.000000
# 14                    51.428571                 70.000000
# 53                    48.000000                 69.000000
# 62                    45.428571                 69.000000
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(10,10), dpi=80)
x = A['นักศึกษา']
y1 = A['คะแนนอาจารย์ที่ปรึกษาคิดเป็น 40%']
y2 = A['คะแนนสอบปากเปล่าคิดเป็น 60%']
 
# plot barschart 
plt.bar(x, y1, label ='advisor',color='#FFE4E1')
plt.bar(x, y2, bottom=y1, label ='oral exam',color='#E6E6FA')
plt.xticks(A.reset_index()['นักศึกษา'],rotation=90)
plt.legend()

# %% [markdown]
# Histogram แสดงจำนวนผู้ได้เกรดต่างๆ

# %%
plt.hist(Grade['Grade'],bins=5,color = '#ADFF2F')
plt.title('GPA')
plt.xlabel('Grades')
plt.ylabel('Number of grades')
plt.legend();
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %% [markdown]
# # 3). Boxplot เปรียบเทียบการกระจายของคะแนนที่อ.กรรมการสอบปากเปล่าแต่ละท่านให้นักศึกษา

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize']=[30,25]

plt.subplot(6,6,1)
a1 = plt.boxplot(advisor1['รวม'])
plt.title('Dr. Thanapong')

plt.subplot(6,6,2)
a2 = plt.boxplot(advisor2['รวม'])
plt.title('Dr. Thippathai')

plt.subplot(6,6,3)
a3 = plt.boxplot(advisor3['รวม'])
plt.title('Dr. Palakorn')

plt.subplot(6,6,4)
a4 = plt.boxplot(advisor4['รวม'])
plt.title('Dr. Wannaporn')

plt.subplot(6,6,5)
a5 = plt.boxplot(advisor5['รวม'])
plt.title('Dr. Uthumporn')

plt.subplot(6,6,6)
a6 = plt.boxplot(advisor6['รวม'])
plt.title('Asst. Prof. Wutthichai')

plt.subplot(6,6,7)
a7 = plt.boxplot(advisor7['รวม'])
plt.title('Asst. Prof. Sukanya')

plt.subplot(6,6,8)
a8 = plt.boxplot(advisor8['รวม'])
plt.title('Assoc. Prof. Wichuda')

plt.subplot(6,6,9)
a9 = plt.boxplot(advisor9['รวม'])
plt.title('Dr. Thanyaporn')

plt.subplot(6,6,10)
a10 = plt.boxplot(advisor10['รวม'])
plt.title('Prof. Yuphaporn')

plt.subplot(6,6,11)
a11 = plt.boxplot(advisor11['รวม'])
plt.title('Assoc. Prof. Thidadeao')

plt.subplot(6,6,12)
a12 = plt.boxplot(advisor12['รวม'])
plt.title('Assoc. Prof. Suphannee')
# Out:
# Text(0.5, 1.0, 'Assoc. Prof. Suphannee')

# %% [markdown]
# # รายชื่อสมาชิก

# %% [markdown]
# นางสาวภรณกนก ภูผาธรรม 633020446-7
#
# นางสาวสุจิรา มันหาท้าว 633021025-6
#
# นางวสาวสุพรรษา ประกอบบุญ 633021026-4
